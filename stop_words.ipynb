# %%
import spacy

# %%
from spacy.lang.en.stop_words import STOP_WORDS
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("This is the Sentence of Apple.inc Company where we are going to detect stopwords from this document")
for token in doc:
    if token.is_stop:
        print(token)
# Out:
# This
# is
# the
# of
# where
# we
# are
# to
# from
# this

# %%
dir(token)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
#  'is_quote',
#  'is_right_punct',
#  'is_sent_end',
#  'is_sent_start',
#  'is_space',
#  'is_stop',
#  'is_title',
#  'is_upper',
#  'lang',
#  'lang_',
#  'left_edge',
#  'lefts',
#  'lemma',
#  'lemma_',
#  'lex',
#  'lex_id',
#  'like_email',
#  'like_num',
#  'like_url',
#  'lower',
#  'lower_',
#  'morph',
#  'n_lefts',
#  'n_rights',
#  'nbor',
#  'norm',
#  'norm_',
#  'orth',
#  'orth_',
#  'pos',
#  'pos_',
#  'prefix',
#  'prefix_',
#  'prob',
#  'rank',
#  'remove_extension',
#  'right_edge',
#  'rights',
#  'sent',
#  'sent_start',
#  'sentiment',
#  'set_extension',
#  'set_morph',
#  'shape',
#  'shape_',
#  'similarity',
#  'subtree',
#  'suffix',
#  'suffix_',
#  'tag',
#  'tag_',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'vector',
#  'vector_norm',
#  'vocab',
#  'whitespace_']

# %%
#Method 1. This builds your logic very fastly
stop=[]
imp=[]
for token in doc:
    if token.is_stop:
        stop.append(token)
    else:
        imp.append(token)
print(imp)
# Out:
# [Sentence, Apple.inc, Company, going, detect, stopwords, document]

# %%
#List Comprihension technique
def preprocess(text):
    doc = nlp(text)
    no_stop_words = [token.text for token in doc if not token.is_stop]#Putting token's text which are not stop words in list
    return no_stop_words

# %%
preprocess("This is the Sentence of Apple.inc Company where we are going to detect stopwords from this document")
# Out:
# ['Sentence',
#  'Apple.inc',
#  'Company',
#  'going',
#  'detect',
#  'stopwords',
#  'document']

# %% [markdown]
# # Mini Project
# ## 1.Downloading kaggle json structure file and perform Stop_words detection and removation program

# %%
import pandas as pd#Importing Library
data = pd.read_json("doj_press.json",lines=True)#Loading Json File in pandas

# %%
data.head(5)
# Out:
#         id                                              title  \
# 0     None       Convicted Bomb Plotter Sentenced to 30 Years
# 1  12-919   $1 Million in Restitution Payments Announced t...
# 2  11-1002  $1 Million Settlement Reached for Natural Reso...
# 3   10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4   18-898  $100 Million Settlement Will Speed Cleanup Wor...
#
#                                             contents  \
# 0  PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# 1    WASHINGTON – North Carolina’s Waccamaw River...
# 2        BOSTON– A $1-million settlement has been...
# 3    WASHINGTON—A federal grand jury in Las Vegas...
# 4  The U.S. Department of Justice, the U.S. Envir...
#
#                         date         topics  \
# 0  2014-10-01T00:00:00-04:00             []
# 1  2012-07-25T00:00:00-04:00             []
# 2  2011-08-03T00:00:00-04:00             []
# 3  2010-01-08T00:00:00-05:00             []
# 4  2018-07-09T00:00:00-04:00  [Environment]
#
#                                      components
# 0            [National Security Division (NSD)]
# 1  [Environment and Natural Resources Division]
# 2  [Environment and Natural Resources Division]
# 3  [Environment and Natural Resources Division]
# 4  [Environment and Natural Resources Division]

# %% [markdown]
# # 2. So going through data i found topics , components , id columns are not important to us

# %%
data['title'].head(4)
#or
#data.title
# Out:
# 0         Convicted Bomb Plotter Sentenced to 30 Years
# 1    $1 Million in Restitution Payments Announced t...
# 2    $1 Million Settlement Reached for Natural Reso...
# 3    10 Las Vegas Men Indicted \r\nfor Falsifying V...
# Name: title, dtype: object

# %%
# drop the columns
#data = data.drop(columns=['topics','id','components'],)

# %%
data.head(2)
# Out:
#         id                                              title  \
# 0     None       Convicted Bomb Plotter Sentenced to 30 Years
# 1  12-919   $1 Million in Restitution Payments Announced t...
#
#                                             contents  \
# 0  PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# 1    WASHINGTON – North Carolina’s Waccamaw River...
#
#                         date topics  \
# 0  2014-10-01T00:00:00-04:00     []
# 1  2012-07-25T00:00:00-04:00     []
#
#                                      components
# 0            [National Security Division (NSD)]
# 1  [Environment and Natural Resources Division]

# %%
data['topics'][10]
# Out:
# []

# %%
#Searching whether any topic have important content or all the topics are empty list
def topic_searching(data):
    for data in data.topics:
        if data != []:
            print(data)# So this will print all the Avaialble data into the topics column

# %%
topic_searching(data) # so we also have important data in topics column so we cannot drop the whole column
# Out:
# ['Environment']
# ['Consumer Protection']
# ['Environment']
# ['False Claims Act', 'Health Care Fraud']
# ['Health Care Fraud', 'False Claims Act']
# ['Consumer Protection', 'Elder Justice']
# ['Consumer Protection', 'StopFraud']
# ['Opioids']
# ['False Claims Act', 'Health Care Fraud']
# ['Drug Trafficking', 'Indian Country Law and Justice']
# ['False Claims Act']
# ['Drug Trafficking']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Tax']
# ['Health Care Fraud']
# ['Drug Trafficking', 'Opioids']
# ['Asset Forfeiture', 'Tax']
# ['Public Corruption']
# ['Civil Rights', 'Human Trafficking']
# ['Civil Rights']
# ['Violent Crime']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud', 'StopFraud']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud']
# ['Tax']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Counterterrorism']
# ['Counterterrorism']
# ['Antitrust']
# ['Counterterrorism']
# ['Antitrust']
# ['Counterterrorism']
# ['Counterterrorism']
# ['Counterterrorism']
# ['Counterterrorism']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Counterterrorism']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Project Safe Childhood']
# ['Identity Theft', 'Tax']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Hate Crimes']
# ['Counterterrorism']
# ['Hate Crimes']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Tax']
# ['Hate Crimes']
# ['Counterterrorism']
# ['Project Safe Childhood']
# ['Hate Crimes']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Opioids', 'Prescription Drugs', 'Health Care Fraud']
# ['Antitrust', 'StopFraud']
# ['StopFraud']
# ['StopFraud']
# ['StopFraud']
# ['StopFraud']
# ['StopFraud']
# ['Antitrust', 'StopFraud']
# ['Antitrust']
# ['StopFraud']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['False Claims Act']
# ['Counterintelligence and Export Control']
# ['Project Safe Childhood']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Project Safe Childhood']
# ['Hate Crimes']
# ['False Claims Act', 'Health Care Fraud']
# ['Drug Trafficking']
# ['Drug Trafficking']
# ['Counterterrorism']
# ['Counterterrorism']
# ['Counterterrorism']
# ['Financial Fraud']
# ['Wildlife']
# ['Counterterrorism']
# ['Violent Crime']
# ['Violent Crime']
# ['Counterterrorism', 'National Security']
# ['False Claims Act']
# ['StopFraud']
# ['Antitrust']
# ['Opioids', 'Cyber Crime', 'Drug Trafficking']
# ['Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud']
# ['Antitrust']
# ['Counterterrorism']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['National Security']
# ['Wildlife']
# ['Counterterrorism']
# ['Consumer Protection']
# ['Access to Justice']
# ['Civil Rights']
# ['Environment']
# ['Consumer Protection']
# ['Wildlife']
# ['Wildlife']
# ['Antitrust', 'Office and Personnel Updates']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Consumer Protection']
# ['False Claims Act', 'Financial Fraud']
# ['Hate Crimes']
# ['Antitrust']
# ['Office and Personnel Updates']
# ['Violent Crime']
# ['Indian Country Law and Justice']
# ['Project Safe Childhood']
# ['Counterterrorism']
# ['Cyber Crime']
# ['Intellectual Property']
# ['Indian Country Law and Justice']
# ['Bankruptcy', 'Financial Fraud']
# ['Tax']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Counterintelligence and Export Control']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Cyber Crime']
# ['Tax']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Public Corruption']
# ['Financial Fraud']
# ['Hate Crimes']
# ['National Security']
# ['Hate Crimes']
# ['Public Corruption']
# ['Project Safe Childhood']
# ['Public Corruption']
# ['Public Corruption']
# ['Indian Country Law and Justice']
# ['Civil Rights']
# ['Financial Fraud', 'Foreign Corruption']
# ['Financial Fraud']
# ['Hate Crimes']
# ['Drug Trafficking']
# ['Drug Trafficking', 'Violent Crime']
# ['Health Care Fraud']
# ['Environment']
# ['Antitrust']
# ['Indian Country Law and Justice']
# ['Indian Country Law and Justice']
# ['Violent Crime']
# ['Violent Crime']
# ['False Claims Act']
# ['False Claims Act']
# ['Civil Rights', 'Violent Crime']
# ['StopFraud']
# ['Cyber Crime', 'Securities, Commodities, & Investment Fraud']
# ['Violent Crime']
# ['Indian Country Law and Justice']
# ['Immigration']
# ['Consumer Protection']
# ['Intellectual Property']
# ['Consumer Protection']
# ['Project Safe Childhood']
# ['Consumer Protection', 'StopFraud']
# ['Indian Country Law and Justice']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Indian Country Law and Justice']
# ['Indian Country Law and Justice']
# ['Access to Justice']
# ['National Security']
# ['Indian Country Law and Justice']
# ['Indian Country Law and Justice']
# ['Access to Justice']
# ['Access to Justice']
# ['Consumer Protection']
# ['Indian Country Law and Justice']
# ['Access to Justice']
# ['Indian Country Law and Justice']
# ['Access to Justice']
# ['Indian Country Law and Justice']
# ['Access to Justice']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Indian Country Law and Justice']
# ['Access to Justice']
# ['Access to Justice']
# ['Consumer Protection']
# ['Civil Rights']
# ['Office and Personnel Updates']
# ['Office and Personnel Updates']
# ['Immigration']
# ['Drug Trafficking', 'Opioids']
# ['Indian Country Law and Justice']
# ['Violent Crime']
# ['Opioids']
# ['Office and Personnel Updates']
# ['Human Trafficking']
# ['Opioids']
# ['Bankruptcy', 'Office and Personnel Updates']
# ['Counterterrorism']
# ['Violent Crime', 'Firearms Offenses']
# ['Immigration']
# ['Hate Crimes']
# ['Asset Forfeiture']
# ['Violent Crime']
# ['Office and Personnel Updates']
# ['Office and Personnel Updates']
# ['Antitrust']
# ['Indian Country Law and Justice']
# ['Human Trafficking']
# ['Grants']
# ['Civil Rights', 'Human Trafficking']
# ['Human Trafficking']
# ['Human Trafficking']
# ['Grants', 'Indian Country Law and Justice']
# ['Antitrust']
# ['Opioids']
# ['Community Outreach']
# ['Hate Crimes']
# ['Environment']
# ['Civil Rights']
# ['Civil Rights']
# ['Office and Personnel Updates']
# ['Community Outreach']
# ['Grants', 'Human Trafficking']
# ['Consumer Protection']
# ['Community Outreach']
# ['Office and Personnel Updates']
# ['Drug Trafficking', 'Grants']
# ['Violent Crime']
# ['Prescription Drugs']
# ['Violent Crime']
# ['Prescription Drugs']
# ['Asset Forfeiture']
# ['Prescription Drugs']
# ['Counterterrorism']
# ['Grants', 'Immigration']
# ['Cyber Crime']
# ['Opioids', 'Prescription Drugs']
# ['Drug Trafficking']
# ['Opioids', 'Drug Trafficking']
# ['Cyber Crime']
# ['Opioids', 'Office and Personnel Updates']
# ['Drug Trafficking']
# ['National Security']
# ['Violent Crime']
# ['Immigration']
# ['Drug Trafficking', 'Opioids', 'Prescription Drugs']
# ['Asset Forfeiture', 'Opioids']
# ['National Security']
# ['Drug Trafficking']
# ['Drug Trafficking']
# ['Immigration']
# ['Immigration']
# ['Prescription Drugs']
# ['Cyber Crime']
# ['Wildlife']
# ['Counterterrorism', 'National Security']
# ['StopFraud']
# ['Consumer Protection', 'Disaster Fraud', 'Financial Fraud']
# ['Intellectual Property']
# ['Antitrust']
# ['Antitrust']
# ['Cyber Crime']
# ['StopFraud']
# ['Consumer Protection']
# ['Financial Fraud', 'Project Safe Childhood']
# ['Hate Crimes']
# ['Drug Trafficking', 'Public Corruption', 'Tax']
# ['Civil Rights', 'Hate Crimes']
# ['Civil Rights']
# ['Tax']
# ['Antitrust']
# ['False Claims Act', 'Health Care Fraud']
# ['Financial Fraud', 'Mortgage Fraud']
# ['StopFraud']
# ['Drug Trafficking']
# ['Opioids', 'Violent Crime', 'Drug Trafficking']
# ['Opioids', 'Violent Crime', 'Drug Trafficking']
# ['Drug Trafficking']
# ['Environment']
# ['False Claims Act']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Disaster Fraud']
# ['Consumer Protection', 'False Claims Act', 'Health Care Fraud']
# ['Antitrust']
# ['False Claims Act']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Civil Rights']
# ['Civil Rights']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act']
# ['Wildlife']
# ['Wildlife']
# ['Health Care Fraud']
# ['Environment']
# ['Consumer Protection']
# ['Labor & Employment', 'Environment']
# ['False Claims Act', 'Health Care Fraud']
# ['Antitrust']
# ['False Claims Act']
# ['False Claims Act']
# ['Immigration']
# ['Civil Rights']
# ['False Claims Act']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Civil Rights', 'Hate Crimes']
# ['Project Safe Childhood']
# ['StopFraud']
# ['Consumer Protection', 'Identity Theft']
# ['Project Safe Childhood']
# ['Securities, Commodities, & Investment Fraud']
# ['Wildlife']
# ['Consumer Protection']
# ['Counterterrorism', 'National Security']
# ['Counterintelligence and Export Control']
# ['Environment', 'Wildlife']
# ['Tax']
# ['National Security']
# ['Tax']
# ['Tax']
# ['Cyber Crime']
# ['Public Corruption']
# ['Counterintelligence and Export Control']
# ['Antitrust']
# ['Antitrust']
# ['Indian Country Law and Justice']
# ['Foreign Corruption', 'Tax']
# ['False Claims Act']
# ['False Claims Act']
# ['Antitrust']
# ['Environment', 'Wildlife']
# ['False Claims Act']
# ['Tax']
# ['Tax']
# ['Mortgage Fraud', 'Tax']
# ['Mortgage Fraud', 'Tax']
# ['Health Care Fraud', 'StopFraud']
# ['Hate Crimes']
# ['Health Care Fraud']
# ['Tax']
# ['Consumer Protection']
# ['False Claims Act', 'Health Care Fraud']
# ['Civil Rights', 'Human Trafficking']
# ['Tax']
# ['Counterterrorism']
# ['Counterintelligence and Export Control']
# ['National Security']
# ['Counterterrorism']
# ['Counterterrorism', 'National Security']
# ['Financial Fraud']
# ['Drug Trafficking']
# ['Project Safe Childhood']
# ['Hate Crimes']
# ['Identity Theft', 'Tax']
# ['Counterterrorism']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Project Safe Childhood']
# ['Consumer Protection']
# ['Firearms Offenses']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Identity Theft', 'Tax']
# ['Counterintelligence and Export Control']
# ['Financial Fraud', 'Tax']
# ['Tax']
# ['Financial Fraud', 'StopFraud']
# ['Consumer Protection']
# ['Project Safe Childhood']
# ['Identity Theft', 'Tax']
# ['Project Safe Childhood']
# ['Counterterrorism', 'National Security']
# ['Project Safe Childhood']
# ['Wildlife']
# ['Counterterrorism', 'Financial Fraud', 'National Security']
# ['Counterintelligence and Export Control', 'National Security']
# ['Environment']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Project Safe Childhood']
# ['Hate Crimes']
# ['Firearms Offenses', 'Violent Crime']
# ['Wildlife']
# ['Project Safe Childhood']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Consumer Protection']
# ['Intellectual Property']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['False Claims Act', 'Health Care Fraud']
# ['Intellectual Property']
# ['Tax']
# ['Tax']
# ['Consumer Protection']
# ['Consumer Protection', 'Financial Fraud']
# ['Identity Theft', 'Tax']
# ['Counterintelligence and Export Control', 'National Security']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Counterintelligence and Export Control']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Consumer Protection']
# ['Financial Fraud', 'StopFraud']
# ['Counterintelligence and Export Control']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Public Corruption']
# ['Wildlife']
# ['Wildlife']
# ['Environment', 'Wildlife']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Antitrust']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control', 'National Security']
# ['Securities, Commodities, & Investment Fraud']
# ['Counterterrorism']
# ['Tax']
# ['Environment', 'Wildlife']
# ['Tax']
# ['False Claims Act', 'Tax']
# ['Tax']
# ['Tax']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud']
# ['Drug Trafficking']
# ['False Claims Act']
# ['Tax']
# ['Intellectual Property']
# ['StopFraud']
# ['StopFraud']
# ['Environment']
# ['StopFraud']
# ['Counterintelligence and Export Control', 'National Security']
# ['Securities, Commodities, & Investment Fraud', 'Tax']
# ['Securities, Commodities, & Investment Fraud', 'Tax']
# ['Immigration']
# ['Foreign Corruption']
# ['Financial Fraud']
# ['Tax']
# ['Financial Fraud', 'Public Corruption', 'StopFraud', 'Tax']
# ['Counterterrorism']
# ['Health Care Fraud']
# ['Hate Crimes']
# ['Tax']
# ['Civil Rights']
# ['Civil Rights']
# ['Hate Crimes']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Counterterrorism']
# ['Counterterrorism']
# ['False Claims Act', 'Health Care Fraud']
# ['Environment']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Tax']
# ['Violent Crime']
# ['Violent Crime']
# ['National Security']
# ['Violent Crime']
# ['Drug Trafficking']
# ['Antitrust']
# ['Consumer Protection']
# ['StopFraud']
# ['Financial Fraud']
# ['Counterintelligence and Export Control', 'National Security']
# ['Counterintelligence and Export Control']
# ['Financial Fraud']
# ['Antitrust']
# ['Public Corruption']
# ['False Claims Act']
# ['Foreign Corruption']
# ['Consumer Protection', 'Health Care Fraud']
# ['Consumer Protection', 'Health Care Fraud']
# ['Counterintelligence and Export Control']
# ['National Security']
# ['Intellectual Property']
# ['Cyber Crime', 'National Security']
# ['Counterintelligence and Export Control', 'National Security']
# ['Counterintelligence and Export Control', 'Cyber Crime', 'National Security']
# ['Counterintelligence and Export Control', 'National Security']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control', 'National Security']
# ['Intellectual Property']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control', 'National Security']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control', 'Cyber Crime', 'National Security']
# ['National Security']
# ['Intellectual Property']
# ['Intellectual Property']
# ['Counterintelligence and Export Control']
# ['False Claims Act']
# ['Consumer Protection']
# ['National Security']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Human Trafficking']
# ['Counterterrorism', 'National Security']
# ['False Claims Act']
# ['Tax']
# ['Environment']
# ['Consumer Protection']
# ['Antitrust']
# ['Health Care Fraud', 'StopFraud']
# ['Health Care Fraud']
# ['Intellectual Property']
# ['Tax']
# ['Consumer Protection']
# ['Opioids']
# ['Drug Trafficking', 'Immigration']
# ['Drug Trafficking']
# ['Drug Trafficking']
# ['Drug Trafficking']
# ['False Claims Act']
# ['Project Safe Childhood']
# ['Wildlife']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Indian Country Law and Justice']
# ['Tax']
# ['Project Safe Childhood']
# ['Tax']
# ['Tax']
# ['StopFraud']
# ['Tax']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Hate Crimes']
# ['Antitrust']
# ['Consumer Protection']
# ['False Claims Act']
# ['False Claims Act', 'Health Care Fraud']
# ['Consumer Protection']
# ['Environment']
# ['Environment']
# ['Counterintelligence and Export Control', 'Cyber Crime', 'National Security']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Public Corruption']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Environment', 'Wildlife']
# ['StopFraud']
# ['Tax']
# ['Tax']
# ['Cyber Crime', 'Intellectual Property']
# ['Antitrust']
# ['Antitrust']
# ['Environment']
# ['Antitrust']
# ['Asset Forfeiture', 'Counterintelligence and Export Control']
# ['Antitrust']
# ['Violent Crime']
# ['Tax']
# ['Project Safe Childhood']
# ['Antitrust']
# ['Antitrust']
# ['Opioids', 'Prescription Drugs']
# ['National Security']
# ['Environment']
# ['Consumer Protection']
# ['Civil Rights']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Consumer Protection']
# ['Tax']
# ['Cyber Crime']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['False Claims Act']
# ['National Security']
# ['Tax']
# ['Consumer Protection']
# ['Financial Fraud', 'Mortgage Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Securities, Commodities, & Investment Fraud']
# ['Tax']
# ['Tax']
# ['Cyber Crime', 'Intellectual Property']
# ['Violent Crime']
# ['Violent Crime']
# ['Violent Crime']
# ['Violent Crime']
# ['Violent Crime']
# ['Environment']
# ['Civil Rights']
# ['Antitrust']
# ['Cyber Crime']
# ['Cyber Crime']
# ['False Claims Act', 'Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud', 'False Claims Act']
# ['Consumer Protection']
# ['Project Safe Childhood']
# ['Cyber Crime']
# ['False Claims Act']
# ['False Claims Act', 'Health Care Fraud']
# ['Antitrust']
# ['Tax']
# ['Tax']
# ['Prescription Drugs']
# ['Opioids']
# ['Prescription Drugs']
# ['Prescription Drugs']
# ['Opioids', 'Prescription Drugs']
# ['Antitrust']
# ['Violent Crime']
# ['Counterterrorism']
# ['Indian Country Law and Justice']
# ['Cyber Crime']
# ['Counterterrorism']
# ['Identity Theft']
# ['Indian Country Law and Justice', 'Violent Crime']
# ['Consumer Protection', 'Elder Justice']
# ['Counterterrorism', 'National Security']
# ['Intellectual Property']
# ['False Claims Act']
# ['False Claims Act']
# ['False Claims Act', 'Financial Fraud']
# ['False Claims Act']
# ['False Claims Act']
# ['Counterintelligence and Export Control', 'National Security']
# ['Counterintelligence and Export Control']
# ['False Claims Act']
# ['False Claims Act']
# ['Civil Rights']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Environment', 'Wildlife']
# ['False Claims Act', 'StopFraud']
# ['False Claims Act']
# ['Immigration']
# ['Immigration']
# ['Immigration']
# ['Immigration']
# ['Health Care Fraud']
# ['Drug Trafficking']
# ['Consumer Protection']
# ['Access to Justice']
# ['Health Care Fraud']
# ['Environment']
# ['Environment']
# ['Environment']
# ['Environment']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Health Care Fraud']
# ['Office and Personnel Updates']
# ['Antitrust']
# ['Asset Forfeiture', 'Wildlife']
# ['Indian Country Law and Justice']
# ['Prescription Drugs', 'Indian Country Law and Justice']
# ['Indian Country Law and Justice']
# ['Indian Country Law and Justice']
# ['Indian Country Law and Justice']
# ['Antitrust']
# ['Office and Personnel Updates']
# ['Opioids']
# ['Intellectual Property']
# ['Community Outreach']
# ['Immigration']
# ['Access to Justice']
# ['Civil Rights']
# ['Indian Country Law and Justice']
# ['Tax']
# ['Drug Trafficking', 'Opioids', 'Prescription Drugs']
# ['Grants']
# ['Indian Country Law and Justice']
# ['Office and Personnel Updates']
# ['Grants']
# ['Grants']
# ['Grants']
# ['Grants', 'Human Trafficking']
# ['Opioids', 'Prescription Drugs']
# ['Grants']
# ['Asset Forfeiture']
# ['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'Health Care Fraud']
# ['Asset Forfeiture']
# ['Environment']
# ['Environment']
# ['Environment']
# ['Access to Justice', 'Civil Rights']
# ['Civil Rights']
# ['Access to Justice', 'Civil Rights']
# ['Consumer Protection']
# ['Immigration']
# ['Consumer Protection']
# ['Immigration', 'National Security']
# ['Environment']
# ['Access to Justice']
# ['Civil Rights']
# ['Access to Justice']
# ['Immigration']
# ['Civil Rights']
# ['Consumer Protection']
# ['Servicemembers Initiative']
# ['Civil Rights']
# ['Elder Justice']
# ['Office and Personnel Updates']
# ['Opioids', 'Office and Personnel Updates']
# ['Opioids', 'Immigration', 'Violent Crime']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Intellectual Property']
# ['Opioids']
# ['Elder Justice', 'Office and Personnel Updates']
# ['Servicemembers Initiative']
# ['Consumer Protection', 'Elder Justice', 'Financial Fraud']
# ['Civil Rights']
# ['Indian Country Law and Justice']
# ['Indian Country Law and Justice']
# ['StopFraud']
# ['Asset Forfeiture']
# ['Project Safe Childhood']
# ['Indian Country Law and Justice']
# ['Opioids', 'Prescription Drugs', 'Drug Trafficking']
# ['Immigration']
# ['Antitrust']
# ['Asset Forfeiture', 'Foreign Corruption']
# ['Antitrust']
# ['Intellectual Property']
# ['Servicemembers Initiative']
# ['Antitrust']
# ['Immigration']
# ['Access to Justice']
# ['StopFraud']
# ['Antitrust']
# ['Antitrust']
# ['Civil Rights']
# ['Health Care Fraud']
# ['Consumer Protection']
# ['Civil Rights']
# ['Civil Rights', 'Immigration']
# ['Immigration']
# ['Immigration']
# ['Access to Justice']
# ['Grants']
# ['Civil Rights']
# ['Human Trafficking']
# ['Grants']
# ['Human Trafficking']
# ['Foreign Corruption']
# ['Project Safe Neighborhoods']
# ['Asset Forfeiture']
# ['Tax']
# ['Tax']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud', 'StopFraud']
# ['Health Care Fraud']
# ['Environment']
# ['Health Care Fraud']
# ['Violent Crime']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Health Care Fraud', 'StopFraud']
# ['Tax']
# ['Financial Fraud', 'Mortgage Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Financial Fraud', 'Securities, Commodities, & Investment Fraud']
# ['Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['False Claims Act', 'Health Care Fraud']
# ['Consumer Protection']
# ['Disaster Fraud']
# ['Foreign Corruption']
# ['Environment']
# ['Environment']
# ['Identity Theft', 'Tax']
# ['Environment']
# ['Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection', 'Health Care Fraud']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection', 'Health Care Fraud']
# ['Consumer Protection', 'Health Care Fraud']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection', 'Elder Justice']
# ['Consumer Protection']
# ['Consumer Protection', 'Health Care Fraud']
# ['Consumer Protection', 'Health Care Fraud']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection', 'Elder Justice']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Identity Theft']
# ['Antitrust']
# ['Antitrust', 'Intellectual Property']
# ['Antitrust']
# ['Antitrust']
# ['Immigration']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Opioids']
# ['False Claims Act']
# ['False Claims Act']
# ['Health Care Fraud']
# ['Consumer Protection', 'Elder Justice']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Environment']
# ['False Claims Act']
# ['Antitrust']
# ['Antitrust']
# ['Firearms Offenses', 'Violent Crime']
# ['StopFraud']
# ['Environment', 'Tax']
# ['False Claims Act']
# ['Cyber Crime']
# ['Drug Trafficking']
# ['Elder Justice']
# ['Health Care Fraud']
# ['Violent Crime']
# ['Health Care Fraud', 'Identity Theft']
# ['Financial Fraud', 'Securities, Commodities, & Investment Fraud']
# ['Health Care Fraud']
# ['Civil Rights', 'Human Trafficking']
# ['Firearms Offenses', 'Violent Crime']
# ['Violent Crime']
# ['Firearms Offenses', 'Violent Crime']
# ['StopFraud']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Antitrust']
# ['False Claims Act', 'Health Care Fraud']
# ['Drug Trafficking', 'Violent Crime']
# ['Intellectual Property']
# ['Counterintelligence and Export Control']
# ['Antitrust', 'StopFraud']
# ['Counterterrorism']
# ['Consumer Protection']
# ['Antitrust']
# ['Foreign Corruption']
# ['Tax']
# ['Environment']
# ['Tax']
# ['Consumer Protection']
# ['Consumer Protection']
# ['False Claims Act']
# ['Environment']
# ['Antitrust']
# ['Environment']
# ['Environment']
# ['Environment', 'Wildlife']
# ['Tax']
# ['Antitrust', 'StopFraud']
# ['Counterterrorism']
# ['Antitrust']
# ['Immigration']
# ['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Counterintelligence and Export Control']
# ['Environment']
# ['Health Care Fraud']
# ['Hate Crimes']
# ['False Claims Act', 'Health Care Fraud']
# ['Consumer Protection']
# ['Tax']
# ['Antitrust']
# ['Opioids', 'Drug Trafficking']
# ['Counterintelligence and Export Control', 'National Security']
# ['Violent Crime']
# ['Tax']
# ['Tax']
# ['Access to Justice', 'Consumer Protection']
# ['Consumer Protection']
# ['Indian Country Law and Justice']
# ['Civil Rights']
# ['Consumer Protection', 'StopFraud']
# ['Environment']
# ['Indian Country Law and Justice']
# ['Hate Crimes']
# ['False Claims Act']
# ['Servicemembers Initiative']
# ['Consumer Protection']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Civil Rights']
# ['Consumer Protection']
# ['Tax']
# ['Consumer Protection']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Civil Rights']
# ['Civil Rights']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Civil Rights']
# ['Intellectual Property']
# ['Intellectual Property']
# ['Consumer Protection']
# ['Consumer Protection', 'StopFraud']
# ['Consumer Protection']
# ['Counterintelligence and Export Control']
# ['Tax']
# ['Tax']
# ['Drug Trafficking']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Firearms Offenses']
# ['Violent Crime']
# ['Civil Rights', 'Hate Crimes']
# ['Project Safe Childhood']
# ['Violent Crime']
# ['Counterterrorism', 'National Security']
# ['Civil Rights']
# ['Violent Crime']
# ['Civil Rights']
# ['Wildlife']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Environment']
# ['Consumer Protection']
# ['Intellectual Property']
# ['Opioids', 'Drug Trafficking', 'Firearms Offenses']
# ['False Claims Act', 'Health Care Fraud', 'StopFraud']
# ['Counterintelligence and Export Control', 'National Security']
# ['Hate Crimes']
# ['Consumer Protection']
# ['Project Safe Childhood']
# ['Hate Crimes']
# ['StopFraud']
# ['False Claims Act', 'Financial Fraud', 'Mortgage Fraud']
# ['Antitrust']
# ['Antitrust']
# ['Consumer Protection', 'Elder Justice']
# ['Consumer Protection']
# ['Drug Trafficking', 'Prescription Drugs', 'Violent Crime']
# ['Indian Country Law and Justice']
# ['False Claims Act']
# ['Cyber Crime']
# ['Opioids']
# ['Environment']
# ['Environment']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Hate Crimes']
# ['Foreign Corruption']
# ['Violent Crime']
# ['Violent Crime']
# ['Consumer Protection']
# ['Health Care Fraud']
# ['Tax']
# ['Violent Crime']
# ['Environment', 'Wildlife']
# ['Antitrust']
# ['Antitrust']
# ['StopFraud', 'Antitrust']
# ['Opioids', 'Health Care Fraud']
# ['Environment']
# ['Antitrust']
# ['Antitrust']
# ['Tax']
# ['Tax']
# ['Public Corruption']
# ['Health Care Fraud', 'StopFraud']
# ['False Claims Act']
# ['StopFraud']
# ['StopFraud']
# ['Tax']
# ['Financial Fraud']
# ['Tax']
# ['False Claims Act', 'Health Care Fraud', 'StopFraud']
# ['False Claims Act']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Consumer Protection']
# ['Health Care Fraud']
# ['Tax']
# ['Tax']
# ['Consumer Protection']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud']
# ['Financial Fraud']
# ['Consumer Protection']
# ['Consumer Protection']
# ['National Security']
# ['Counterterrorism', 'National Security']
# ['National Security']
# ['Project Safe Childhood']
# ['Civil Rights', 'Human Trafficking']
# ['Counterterrorism']
# ['Hate Crimes']
# ['Civil Rights', 'Human Trafficking']
# ['Tax']
# ['Tax']
# ['Project Safe Childhood']
# ['Civil Rights', 'Human Trafficking']
# ['Public Corruption']
# ['Counterintelligence and Export Control']
# ['Counterterrorism']
# ['Asset Forfeiture', 'Cyber Crime']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Civil Rights', 'Hate Crimes']
# ['Hate Crimes']
# ['Public Corruption']
# ['Tax']
# ['Consumer Protection']
# ['Identity Theft']
# ['Civil Rights', 'Human Trafficking']
# ['Project Safe Childhood']
# ['Counterterrorism']
# ['Civil Rights', 'Human Trafficking']
# ['National Security']
# ['StopFraud']
# ['Counterintelligence and Export Control']
# ['Intellectual Property']
# ['Cyber Crime', 'Identity Theft']
# ['Health Care Fraud', 'StopFraud']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Civil Rights']
# ['Civil Rights', 'Human Trafficking']
# ['Civil Rights', 'Hate Crimes']
# ['Consumer Protection']
# ['Hate Crimes']
# ['Consumer Protection']
# ['Civil Rights', 'Counterterrorism', 'National Security']
# ['Identity Theft', 'Tax']
# ['Consumer Protection']
# ['Tax']
# ['Tax']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Counterterrorism']
# ['Tax']
# ['Tax']
# ['Tax', 'Identity Theft']
# ['Tax']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['False Claims Act']
# ['Tax']
# ['National Security']
# ['National Security']
# ['Project Safe Childhood']
# ['Counterintelligence and Export Control', 'National Security']
# ['Tax']
# ['Consumer Protection']
# ['Consumer Protection']
# ['National Security']
# ['Antitrust']
# ['Human Trafficking']
# ['Human Smuggling', 'Immigration']
# ['Human Smuggling']
# ['False Claims Act', 'Health Care Fraud']
# ['Public Corruption']
# ['Public Corruption']
# ['Project Safe Childhood']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Tax']
# ['Civil Rights']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Foreign Corruption']
# ['StopFraud']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Counterterrorism']
# ['Tax']
# ['Consumer Protection', 'Mortgage Fraud']
# ['Environment']
# ['Consumer Protection']
# ['Antitrust']
# ['Antitrust']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Immigration']
# ['Civil Rights']
# ['Financial Fraud']
# ['Public Corruption']
# ['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Financial Fraud']
# ['Tax']
# ['Public Corruption', 'Tax']
# ['Wildlife']
# ['Civil Rights']
# ['Cyber Crime', 'Intellectual Property']
# ['Civil Rights']
# ['Project Safe Childhood']
# ['Securities, Commodities, & Investment Fraud']
# ['Financial Fraud', 'StopFraud']
# ['Financial Fraud']
# ['Tax']
# ['Securities, Commodities, & Investment Fraud']
# ['Financial Fraud']
# ['Antitrust', 'StopFraud']
# ['Antitrust']
# ['Public Corruption']
# ['Antitrust']
# ['Financial Fraud']
# ['Public Corruption']
# ['Public Corruption']
# ['Health Care Fraud']
# ['Financial Fraud']
# ['Environment', 'Financial Fraud']
# ['StopFraud', 'Tax']
# ['Public Corruption']
# ['Public Corruption']
# ['StopFraud']
# ['Counterintelligence and Export Control', 'National Security']
# ['False Claims Act', 'Health Care Fraud']
# ['Securities, Commodities, & Investment Fraud']
# ['Financial Fraud']
# ['Financial Fraud']
# ['Securities, Commodities, & Investment Fraud']
# ['StopFraud']
# ['StopFraud']
# ['Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Health Care Fraud']
# ['Public Corruption']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control']
# ['Public Corruption']
# ['Project Safe Childhood']
# ['Antitrust']
# ['Antitrust']
# ['Drug Trafficking']
# ['Financial Fraud', 'Public Corruption']
# ['National Security']
# ['Counterintelligence and Export Control', 'National Security']
# ['StopFraud']
# ['Public Corruption']
# ['Public Corruption']
# ['Financial Fraud']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Elder Justice', 'Public Corruption', 'Tax']
# ['Public Corruption']
# ['Tax']
# ['Antitrust']
# ['StopFraud']
# ['StopFraud']
# ['Public Corruption']
# ['Counterintelligence and Export Control']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control']
# ['Public Corruption']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['StopFraud']
# ['Public Corruption']
# ['Public Corruption']
# ['Securities, Commodities, & Investment Fraud', 'Tax']
# ['Tax']
# ['Tax']
# ['Antitrust']
# ['Financial Fraud']
# ['Project Safe Childhood']
# ['Health Care Fraud']
# ['Intellectual Property']
# ['Public Corruption']
# ['Public Corruption']
# ['StopFraud']
# ['Public Corruption']
# ['Financial Fraud']
# ['Consumer Protection', 'StopFraud']
# ['Tax']
# ['Tax']
# ['Antitrust']
# ['Antitrust']
# ['Public Corruption']
# ['Tax']
# ['Public Corruption']
# ['Public Corruption']
# ['StopFraud']
# ['StopFraud']
# ['Antitrust']
# ['StopFraud']
# ['Financial Fraud']
# ['Public Corruption']
# ['Health Care Fraud']
# ['Financial Fraud']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Counterintelligence and Export Control']
# ['Public Corruption']
# ['StopFraud']
# ['False Claims Act']
# ['StopFraud']
# ['Public Corruption']
# ['Tax']
# ['Human Smuggling', 'Immigration', 'Violent Crime']
# ['Human Smuggling', 'Violent Crime']
# ['Health Care Fraud', 'StopFraud']
# ['Health Care Fraud']
# ['Tax']
# ['Public Corruption']
# ['Public Corruption']
# ['Financial Fraud', 'Foreign Corruption', 'Public Corruption']
# ['Financial Fraud', 'Foreign Corruption']
# ['Foreign Corruption']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Financial Fraud']
# ['Financial Fraud']
# ['Securities, Commodities, & Investment Fraud']
# ['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Tax']
# ['Health Care Fraud']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Hate Crimes']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Public Corruption']
# ['StopFraud', 'Tax']
# ['Civil Rights']
# ['Civil Rights']
# ['Consumer Protection']
# ['StopFraud']
# ['Financial Fraud']
# ['Public Corruption', 'Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Cyber Crime']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Public Corruption']
# ['Civil Rights']
# ['Civil Rights']
# ['Identity Theft', 'Public Corruption']
# ['Tax']
# ['Tax']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Tax']
# ['Civil Rights']
# ['Tax']
# ['Tax']
# ['Drug Trafficking']
# ['Public Corruption']
# ['Civil Rights']
# ['Civil Rights']
# ['Project Safe Childhood']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Securities, Commodities, & Investment Fraud', 'Tax']
# ['Civil Rights']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Public Corruption']
# ['Antitrust']
# ['Antitrust']
# ['Immigration']
# ['Public Corruption', 'Tax']
# ['Civil Rights']
# ['Tax']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Antitrust']
# ['Project Safe Childhood']
# ['Civil Rights']
# ['Antitrust']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Financial Fraud', 'StopFraud']
# ['StopFraud', 'Tax']
# ['Public Corruption']
# ['Tax']
# ['Public Corruption']
# ['Counterterrorism', 'National Security']
# ['Project Safe Childhood']
# ['Tax']
# ['StopFraud']
# ['Tax']
# ['Tax']
# ['Counterintelligence and Export Control']
# ['Opioids', 'Public Corruption', 'Drug Trafficking']
# ['Opioids', 'Public Corruption']
# ['Civil Rights']
# ['Civil Rights']
# ['StopFraud']
# ['StopFraud']
# ['Consumer Protection']
# ['Public Corruption']
# ['Civil Rights']
# ['Civil Rights']
# ['Tax']
# ['Tax']
# ['Consumer Protection', 'False Claims Act']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Foreign Corruption']
# ['False Claims Act', 'Health Care Fraud']
# ['Foreign Corruption']
# ['National Security']
# ['National Security']
# ['Health Care Fraud']
# ['Financial Fraud', 'StopFraud']
# ['False Claims Act', 'Health Care Fraud']
# ['Health Care Fraud']
# ['Tax']
# ['Tax']
# ['Tax', 'Health Care Fraud']
# ['Antitrust']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Prescription Drugs', 'Consumer Protection', 'Health Care Fraud']
# ['Counterterrorism']
# ['Tax']
# ['Financial Fraud']
# ['Tax']
# ['Antitrust']
# ['Financial Fraud']
# ['Foreign Corruption']
# ['Tax']
# ['Health Care Fraud']
# ['Civil Rights', 'Firearms Offenses']
# ['Public Corruption']
# ['Financial Fraud']
# ['Civil Rights']
# ['Civil Rights']
# ['Public Corruption']
# ['Public Corruption']
# ['Antitrust', 'Financial Fraud', 'Securities, Commodities, & Investment Fraud']
# ['Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Antitrust']
# ['StopFraud']
# ['False Claims Act']
# ['Public Corruption']
# ['Public Corruption']
# ['Cyber Crime']
# ['Public Corruption']
# ['Financial Fraud', 'Public Corruption']
# ['Financial Fraud']
# ['Civil Rights']
# ['Public Corruption']
# ['Financial Fraud', 'Foreign Corruption']
# ['Financial Fraud']
# ['Public Corruption']
# ['Public Corruption']
# ['Identity Theft', 'Tax']
# ['Cyber Crime', 'Intellectual Property']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Cyber Crime']
# ['Civil Rights']
# ['Civil Rights']
# ['Securities, Commodities, & Investment Fraud']
# ['Financial Fraud']
# ['Public Corruption']
# ['Public Corruption', 'StopFraud']
# ['Civil Rights']
# ['Environment']
# ['Environment']
# ['Tax']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Identity Theft', 'Tax']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Tax']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Antitrust']
# ['Antitrust']
# ['Hate Crimes']
# ['Civil Rights']
# ['Securities, Commodities, & Investment Fraud']
# ['Securities, Commodities, & Investment Fraud']
# ['Securities, Commodities, & Investment Fraud']
# ['Securities, Commodities, & Investment Fraud']
# ['Tax']
# ['Tax']
# ['National Security']
# ['Project Safe Childhood']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Tax']
# ['Project Safe Childhood']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Cyber Crime']
# ['Public Corruption']
# ['Project Safe Childhood']
# ['Counterintelligence and Export Control', 'Cyber Crime', 'National Security']
# ['National Security']
# ['Project Safe Childhood']
# ['Cyber Crime']
# ['Cyber Crime', 'Intellectual Property']
# ['Tax']
# ['Financial Fraud']
# ['Financial Fraud', 'Public Corruption']
# ['Environment']
# ['Counterintelligence and Export Control', 'National Security']
# ['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Financial Fraud']
# ['Public Corruption']
# ['Cyber Crime']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Tax']
# ['Tax']
# ['Financial Fraud']
# ['StopFraud']
# ['Tax']
# ['Tax']
# ['Environment']
# ['Project Safe Neighborhoods']
# ['Opioids']
# ['Cyber Crime']
# ['Intellectual Property']
# ['Opioids']
# ['Intellectual Property']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Indian Country Law and Justice']
# ['Foreign Corruption']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Asset Forfeiture', 'Counterintelligence and Export Control', 'National Security']
# ['National Security']
# ['Identity Theft', 'Tax']
# ['Health Care Fraud']
# ['Civil Rights']
# ['Public Corruption']
# ['Intellectual Property']
# ['Hate Crimes']
# ['Drug Trafficking']
# ['Hate Crimes']
# ['Tax']
# ['Environment', 'Wildlife']
# ['Counterterrorism', 'National Security']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Violent Crime', 'Firearms Offenses']
# ['Firearms Offenses', 'Violent Crime']
# ['StopFraud']
# ['Antitrust']
# ['Drug Trafficking', 'Violent Crime']
# ['Drug Trafficking', 'Firearms Offenses', 'Violent Crime']
# ['False Claims Act']
# ['Tax']
# ['Antitrust']
# ['Antitrust']
# ['Environment']
# ['Civil Rights', 'Hate Crimes']
# ['Disaster Fraud']
# ['Drug Trafficking', 'Violent Crime']
# ['Drug Trafficking']
# ['Drug Trafficking', 'Public Corruption']
# ['Counterterrorism', 'National Security']
# ['Cyber Crime', 'Intellectual Property']
# ['Civil Rights', 'Human Trafficking']
# ['Civil Rights', 'Human Trafficking']
# ['Antitrust', 'StopFraud', 'Tax']
# ['StopFraud']
# ['Cyber Crime']
# ['Counterterrorism', 'National Security']
# ['Antitrust']
# ['Antitrust']
# ['Hate Crimes']
# ['False Claims Act']
# ['Consumer Protection']
# ['False Claims Act']
# ['Project Safe Childhood']
# ['Human Trafficking']
# ['Tax']
# ['Public Corruption', 'Health Care Fraud', 'Financial Fraud']
# ['Financial Fraud']
# ['Environment']
# ['Financial Fraud']
# ['Securities, Commodities, & Investment Fraud']
# ['Foreign Corruption']
# ['Financial Fraud', 'Foreign Corruption']
# ['Opioids', 'Health Care Fraud', 'False Claims Act']
# ['Violent Crime']
# ['Environment']
# ['Environment']
# ['StopFraud']
# ['Financial Fraud', 'Foreign Corruption']
# ['Environment']
# ['Consumer Protection']
# ['False Claims Act', 'Health Care Fraud']
# ['Consumer Protection', 'False Claims Act']
# ['Tax']
# ['StopFraud']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Consumer Protection']
# ['Tax']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud']
# ['Tax']
# ['Immigration']
# ['Consumer Protection']
# ['Identity Theft', 'Tax']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Immigration']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['StopFraud']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['StopFraud']
# ['Antitrust']
# ['Antitrust', 'Financial Fraud']
# ['Antitrust']
# ['Consumer Protection']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Consumer Protection', 'Elder Justice']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Environment']
# ['Environment']
# ['Environment']
# ['False Claims Act']
# ['Consumer Protection']
# ['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Consumer Protection']
# ['Financial Fraud']
# ['Consumer Protection']
# ['Counterintelligence and Export Control', 'National Security']
# ['Consumer Protection']
# ['Consumer Protection']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud']
# ['Consumer Protection']
# ['False Claims Act']
# ['False Claims Act', 'Health Care Fraud']
# ['Project Safe Childhood']
# ['Environment']
# ['National Security']
# ['Hate Crimes']
# ['Antitrust']
# ['Environment']
# ['Civil Rights']
# ['Antitrust']
# ['Environment']
# ['Hate Crimes', 'Human Trafficking', 'Violent Crime']
# ['Asset Forfeiture']
# ['Drug Trafficking']
# ['Drug Trafficking']
# ['Antitrust']
# ['Counterterrorism', 'National Security']
# ['Environment']
# ['Counterterrorism', 'National Security']
# ['Tax']
# ['Counterterrorism']
# ['Environment']
# ['Environment']
# ['False Claims Act']
# ['Opioids', 'Health Care Fraud']
# ['Health Care Fraud']
# ['False Claims Act']
# ['False Claims Act', 'Health Care Fraud']
# ['Antitrust']
# ['Civil Rights', 'Drug Trafficking', 'Human Trafficking']
# ['Drug Trafficking']
# ['Public Corruption', 'StopFraud']
# ['Environment']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['False Claims Act']
# ['Health Care Fraud']
# ['Health Care Fraud', 'StopFraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Financial Fraud']
# ['Counterterrorism']
# ['Public Corruption']
# ['Violent Crime']
# ['Counterterrorism']
# ['Environment']
# ['StopFraud']
# ['False Claims Act', 'Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud', 'StopFraud']
# ['StopFraud']
# ['Tax']
# ['Health Care Fraud']
# ['Tax']
# ['Health Care Fraud']
# ['StopFraud']
# ['Identity Theft', 'Tax']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Environment', 'StopFraud']
# ['Hate Crimes']
# ['Counterterrorism']
# ['Opioids', 'Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Human Trafficking']
# ['Financial Fraud']
# ['Human Trafficking']
# ['Tax']
# ['Health Care Fraud']
# ['StopFraud']
# ['Civil Rights']
# ['Civil Rights']
# ['False Claims Act']
# ['StopFraud']
# ['Civil Rights']
# ['Civil Rights', 'Hate Crimes']
# ['Civil Rights', 'Hate Crimes']
# ['Tax']
# ['Tax']
# ['Identity Theft']
# ['Identity Theft']
# ['Identity Theft', 'Tax']
# ['Consumer Protection']
# ['Human Trafficking', 'Project Safe Childhood']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Counterterrorism', 'National Security']
# ['Project Safe Childhood']
# ['Counterterrorism']
# ['Tax']
# ['Consumer Protection']
# ['False Claims Act', 'Health Care Fraud']
# ['Identity Theft', 'Tax']
# ['Human Trafficking', 'Project Safe Childhood']
# ['Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Immigration']
# ['False Claims Act']
# ['Hate Crimes']
# ['Human Trafficking']
# ['Prescription Drugs']
# ['Project Safe Childhood']
# ['Counterterrorism', 'National Security']
# ['Securities, Commodities, & Investment Fraud']
# ['Hate Crimes']
# ['Tax']
# ['Hate Crimes']
# ['Counterterrorism']
# ['Hate Crimes']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Hate Crimes']
# ['Tax']
# ['False Claims Act', 'Health Care Fraud']
# ['Securities, Commodities, & Investment Fraud']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Counterterrorism']
# ['Tax']
# ['National Security']
# ['False Claims Act']
# ['Cyber Crime']
# ['Antitrust']
# ['Indian Country Law and Justice']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Counterterrorism', 'National Security']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Antitrust']
# ['Health Care Fraud']
# ['Counterintelligence and Export Control']
# ['Project Safe Childhood']
# ['Antitrust']
# ['Counterterrorism', 'National Security']
# ['Intellectual Property']
# ['StopFraud']
# ['StopFraud']
# ['Financial Fraud']
# ['Consumer Protection', 'StopFraud']
# ['Environment', 'Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Consumer Protection']
# ['False Claims Act', 'Health Care Fraud']
# ['Hate Crimes']
# ['Civil Rights', 'Hate Crimes']
# ['Counterintelligence and Export Control']
# ['Cyber Crime']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Immigration']
# ['Wildlife']
# ['Wildlife']
# ['Environment']
# ['Wildlife']
# ['Antitrust']
# ['False Claims Act']
# ['Identity Theft', 'Tax']
# ['Counterterrorism', 'Cyber Crime', 'National Security']
# ['Counterterrorism']
# ['Counterterrorism', 'Cyber Crime', 'National Security']
# ['Counterterrorism', 'Cyber Crime', 'National Security']
# ['Counterterrorism']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Consumer Protection']
# ['Environment']
# ['False Claims Act']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection', 'Financial Fraud']
# ['Consumer Protection']
# ['Counterterrorism']
# ['Antitrust']
# ['Antitrust']
# ['False Claims Act']
# ['Opioids', 'Violent Crime', 'Drug Trafficking', 'Firearms Offenses']
# ['Consumer Protection']
# ['False Claims Act', 'Health Care Fraud']
# ['Elder Justice']
# ['Cyber Crime']
# ['National Security']
# ['Cyber Crime']
# ['National Security']
# ['National Security']
# ['Immigration']
# ['StopFraud']
# ['Financial Fraud', 'Foreign Corruption']
# ['Environment']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Antitrust']
# ['Consumer Protection']
# ['Tax']
# ['Civil Rights']
# ['Hate Crimes']
# ['Civil Rights']
# ['Counterintelligence and Export Control']
# ['Counterterrorism']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Project Safe Childhood']
# ['Civil Rights', 'Hate Crimes']
# ['Securities, Commodities, & Investment Fraud', 'Tax']
# ['Counterterrorism']
# ['Consumer Protection']
# ['Hate Crimes']
# ['Counterterrorism', 'National Security']
# ['Indian Country Law and Justice']
# ['Indian Country Law and Justice']
# ['Civil Rights']
# ['Civil Rights', 'StopFraud']
# ['StopFraud']
# ['Antitrust']
# ['Civil Rights']
# ['Drug Trafficking']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Civil Rights']
# ['Access to Justice']
# ['Access to Justice', 'Elder Justice', 'Grants']
# ['Consumer Protection']
# ['StopFraud']
# ['Civil Rights']
# ['Civil Rights', 'StopFraud']
# ['Civil Rights']
# ['Civil Rights', 'StopFraud']
# ['Elder Justice']
# ['Consumer Protection', 'Elder Justice', 'StopFraud']
# ['Environment']
# ['Environment', 'Labor & Employment']
# ['Environment']
# ['Consumer Protection']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Consumer Protection', 'Elder Justice']
# ['Access to Justice', 'Civil Rights']
# ['Antitrust']
# ['Antitrust']
# ['Civil Rights']
# ['Antitrust']
# ['Environment']
# ['Civil Rights']
# ['Consumer Protection', 'StopFraud']
# ['Financial Fraud', 'Mortgage Fraud', 'StopFraud']
# ['Civil Rights']
# ['Civil Rights']
# ['Grants']
# ['Grants']
# ['Grants']
# ['Grants']
# ['Grants']
# ['Grants']
# ...
# ['Consumer Protection']
# ['Mortgage Fraud']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Antitrust']
# ['False Claims Act', 'Health Care Fraud']
# ['Environment']
# ['Consumer Protection']
# ['Cyber Crime']
# ['Human Trafficking']
# ['Counterintelligence and Export Control', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Civil Rights']
# ['Public Corruption']
# ['Civil Rights']
# ['StopFraud']
# ['StopFraud']
# ['StopFraud']
# ['Civil Rights']
# ['Antitrust']
# ['Antitrust']
# ['StopFraud']
# ['StopFraud']
# ['Hate Crimes']
# ['Antitrust']
# ['Identity Theft', 'Tax']
# ['Antitrust']
# ['Violent Crime']
# ['Hate Crimes']
# ['False Claims Act']
# ['Hate Crimes']
# ['Identity Theft', 'Tax']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Health Care Fraud']
# ['Hate Crimes']
# ['Securities, Commodities, & Investment Fraud']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Immigration']
# ['Health Care Fraud']
# ['Intellectual Property']
# ['Project Safe Childhood']
# ['Antitrust']
# ['Counterterrorism', 'National Security']
# ['Health Care Fraud']
# ['Public Corruption']
# ['Public Corruption']
# ['Drug Trafficking']
# ['Violent Crime']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Counterterrorism']
# ['Wildlife']
# ['Environment']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Health Care Fraud']
# ['Counterintelligence and Export Control']
# ['Counterterrorism']
# ['Tax']
# ['Civil Rights']
# ['Consumer Protection']
# ['Antitrust']
# ['Counterterrorism']
# ['Violent Crime']
# ['Public Corruption']
# ['StopFraud']
# ['Cyber Crime', 'Financial Fraud', 'Identity Theft']
# ['Cyber Crime', 'Financial Fraud']
# ['StopFraud']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Hate Crimes']
# ['Identity Theft', 'Tax']
# ['Hate Crimes']
# ['Financial Fraud']
# ['Antitrust']
# ['Cyber Crime', 'Identity Theft']
# ['Hate Crimes']
# ['Environment', 'Securities, Commodities, & Investment Fraud']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Violent Crime']
# ['Hate Crimes']
# ['Tax']
# ['Tax']
# ['Firearms Offenses', 'Violent Crime']
# ['Environment', 'Wildlife']
# ['Disaster Fraud']
# ['Consumer Protection']
# ['Environment']
# ['Counterterrorism', 'National Security']
# ['Environment']
# ['Environment']
# ['Environment']
# ['Antitrust']
# ['Counterterrorism', 'National Security']
# ['Foreign Corruption']
# ['Financial Fraud']
# ['Public Corruption']
# ['Wildlife']
# ['Antitrust']
# ['Environment']
# ['Environment']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control', 'National Security']
# ['Environment']
# ['Opioids', 'Violent Crime', 'Drug Trafficking']
# ['Hate Crimes']
# ['Identity Theft']
# ['StopFraud']
# ['Health Care Fraud']
# ['Opioids', 'Violent Crime', 'Drug Trafficking']
# ['Violent Crime']
# ['Violent Crime']
# ['Violent Crime']
# ['Cyber Crime', 'National Security']
# ['Violent Crime']
# ['Human Trafficking', 'Project Safe Childhood']
# ['Project Safe Childhood']
# ['StopFraud']
# ['StopFraud']
# ['Civil Rights', 'Human Trafficking']
# ['Violent Crime']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Violent Crime']
# ['Violent Crime']
# ['Drug Trafficking', 'Violent Crime']
# ['Hate Crimes']
# ['Cyber Crime']
# ['Hate Crimes']
# ['Identity Theft', 'Tax']
# ['Environment']
# ['StopFraud', 'Tax']
# ['Counterintelligence and Export Control']
# ['Foreign Corruption']
# ['Counterintelligence and Export Control']
# ['Counterterrorism', 'National Security']
# ['Hate Crimes']
# ['Wildlife']
# ['Consumer Protection', 'Mortgage Fraud']
# ['StopFraud']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud']
# ['Violent Crime']
# ['Tax']
# ['Consumer Protection']
# ['Financial Fraud']
# ['Hate Crimes']
# ['Securities, Commodities, & Investment Fraud']
# ['False Claims Act']
# ['Public Corruption']
# ['Elder Justice']
# ['Health Care Fraud']
# ['National Security']
# ['Civil Rights', 'Immigration']
# ['Human Trafficking']
# ['Consumer Protection', 'Elder Justice']
# ['Human Trafficking']
# ['Tax']
# ['Public Corruption']
# ['Consumer Protection', 'Prescription Drugs']
# ['Antitrust']
# ['Antitrust']
# ['StopFraud']
# ['Counterterrorism', 'National Security']
# ['False Claims Act', 'Health Care Fraud']
# ['Counterterrorism']
# ['Environment']
# ['Environment']
# ['Wildlife']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Financial Fraud']
# ['Civil Rights']
# ['Public Corruption']
# ['Antitrust', 'Financial Fraud', 'StopFraud']
# ['Securities, Commodities, & Investment Fraud']
# ['Public Corruption']
# ['Public Corruption', 'StopFraud']
# ['Civil Rights']
# ['Antitrust', 'Securities, Commodities, & Investment Fraud']
# ['StopFraud']
# ['Antitrust', 'Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Securities, Commodities, & Investment Fraud']
# ['Public Corruption']
# ['Securities, Commodities, & Investment Fraud']
# ['Civil Rights']
# ['Antitrust']
# ['Tax']
# ['Antitrust']
# ['Antitrust', 'Financial Fraud', 'StopFraud']
# ['Antitrust']
# ['Environment']
# ['Human Trafficking']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Identity Theft']
# ['Counterterrorism']
# ['Identity Theft', 'Tax']
# ['Violent Crime']
# ['Hate Crimes']
# ['False Claims Act']
# ['Consumer Protection']
# ['National Security']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Securities, Commodities, & Investment Fraud', 'Financial Fraud']
# ['Environment']
# ['Counterintelligence and Export Control']
# ['Antitrust']
# ['Antitrust']
# ['Civil Rights', 'Hate Crimes']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Consumer Protection']
# ['Human Trafficking']
# ['Identity Theft', 'Tax']
# ['Health Care Fraud', 'StopFraud']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Violent Crime']
# ['Violent Crime']
# ['Project Safe Childhood']
# ['Identity Theft', 'Tax']
# ['Counterterrorism']
# ['Foreign Corruption']
# ['Violent Crime']
# ['Project Safe Childhood']
# ['Counterintelligence and Export Control']
# ['Counterterrorism']
# ['Hate Crimes']
# ['Tax']
# ['Consumer Protection']
# ['Violent Crime']
# ['Violent Crime']
# ['Consumer Protection']
# ['Wildlife']
# ['Environment']
# ['Hate Crimes']
# ['Identity Theft']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Counterterrorism', 'National Security']
# ['Human Trafficking']
# ['Identity Theft', 'Tax']
# ['Health Care Fraud']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Tax']
# ['Tax']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Intellectual Property']
# ['Health Care Fraud']
# ['Counterterrorism']
# ['Tax']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['StopFraud', 'Antitrust']
# ['Antitrust']
# ['StopFraud']
# ['Antitrust', 'StopFraud']
# ['StopFraud']
# ['Antitrust']
# ['Tax']
# ['Civil Rights', 'Hate Crimes']
# ['Violent Crime']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Consumer Protection']
# ['Consumer Protection', 'Prescription Drugs']
# ['Tax']
# ['Consumer Protection']
# ['Health Care Fraud']
# ['Consumer Protection']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Counterterrorism', 'National Security']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Cyber Crime']
# ['Consumer Protection', 'Prescription Drugs']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Public Corruption']
# ['StopFraud']
# ['Violent Crime']
# ['Hate Crimes']
# ['Financial Fraud', 'Tax']
# ['Tax']
# ['Counterterrorism']
# ['Environment']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Civil Rights', 'Hate Crimes']
# ['Civil Rights']
# ['Environment']
# ['Counterterrorism']
# ['Counterterrorism', 'National Security']
# ['Hate Crimes']
# ['Health Care Fraud', 'StopFraud']
# ['Counterterrorism']
# ['Counterterrorism', 'National Security']
# ['Environment']
# ['Environment']
# ['Environment']
# ['StopFraud']
# ['Counterintelligence and Export Control', 'National Security']
# ['Cyber Crime']
# ['Antitrust']
# ['Environment']
# ['Environment']
# ['Antitrust']
# ['False Claims Act']
# ['False Claims Act', 'Financial Fraud', 'Mortgage Fraud']
# ['Indian Country Law and Justice']
# ['Indian Country Law and Justice']
# ['Drug Trafficking']
# ['Environment']
# ['Environment']
# ['Environment', 'Indian Country Law and Justice']
# ['Environment']
# ['Civil Rights']
# ['Drug Trafficking']
# ['Counterterrorism']
# ['Environment']
# ['Consumer Protection', 'Health Care Fraud']
# ['Financial Fraud']
# ['Environment', 'Indian Country Law and Justice']
# ['Consumer Protection', 'Environment']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Environment']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Immigration']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['False Claims Act', 'Health Care Fraud']
# ['Elder Justice', 'False Claims Act', 'Health Care Fraud']
# ['Opioids']
# ['False Claims Act', 'Mortgage Fraud', 'StopFraud']
# ['False Claims Act', 'Mortgage Fraud']
# ['False Claims Act']
# ['Consumer Protection']
# ['False Claims Act']
# ['Consumer Protection']
# ['False Claims Act']
# ['False Claims Act']
# ['Consumer Protection']
# ['False Claims Act']
# ['False Claims Act']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud', 'StopFraud']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act']
# ['Project Safe Childhood']
# ['False Claims Act']
# ['Civil Rights']
# ['Environment']
# ['False Claims Act', 'Health Care Fraud']
# ['Asset Forfeiture', 'Foreign Corruption']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Asset Forfeiture', 'Foreign Corruption']
# ['False Claims Act']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act', 'Health Care Fraud']
# ['False Claims Act']
# ['False Claims Act']
# ['False Claims Act']
# ['False Claims Act']
# ['Environment']
# ['Financial Fraud', 'Mortgage Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']
# ['Tax']
# ['Consumer Protection']
# ['False Claims Act']
# ['False Claims Act', 'StopFraud']
# ['Environment']
# ['Violent Crime']
# ['Violent Crime']
# ['Drug Trafficking']
# ['False Claims Act', 'Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Health Care Fraud']
# ['Opioids', 'Health Care Fraud']
# ['Tax']
# ['Counterterrorism', 'National Security']
# ['False Claims Act']
# ['Counterterrorism', 'National Security']
# ['Environment']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Public Corruption']
# ['Office and Personnel Updates']
# ['Office and Personnel Updates']
# ['StopFraud']
# ['Civil Rights']
# ['Drug Trafficking', 'Firearms Offenses']
# ['Consumer Protection']
# ['Community Outreach']
# ['Indian Country Law and Justice']
# ['Office and Personnel Updates']
# ['Office and Personnel Updates']
# ['Cyber Crime', 'Intellectual Property']
# ['Civil Rights']
# ['Intellectual Property']
# ['Counterintelligence and Export Control']
# ['Counterintelligence and Export Control']
# ['Counterterrorism']
# ['Consumer Protection']
# ['Counterterrorism']
# ['Consumer Protection']
# ['Counterterrorism']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Public Corruption']
# ['Environment']
# ['Opioids', 'Grants']
# ['Civil Rights']
# ['Civil Rights']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Antitrust']
# ['Environment']
# ['Public Corruption']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['False Claims Act', 'Public Corruption']
# ['False Claims Act']
# ['Consumer Protection']
# ['Environment']
# ['False Claims Act']
# ['Elder Justice', 'Financial Fraud', 'StopFraud']
# ['Violent Crime']
# ['Violent Crime']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption', 'StopFraud']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['Public Corruption']
# ['National Security']
# ['Counterintelligence and Export Control']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Tax']
# ['Tax']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Asset Forfeiture', 'Foreign Corruption']
# ['National Security']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Bankruptcy']
# ['Consumer Protection']
# ['Consumer Protection', 'Securities, Commodities, & Investment Fraud']
# ['Civil Rights', 'Cyber Crime']
# ['Hate Crimes']
# ['False Claims Act', 'Mortgage Fraud']
# ['Environment']
# ['Firearms Offenses', 'Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Hate Crimes']
# ['Tax']
# ['Counterterrorism']
# ['Counterterrorism']
# ['Counterterrorism', 'National Security']
# ['Tax']
# ['Immigration']
# ['Opioids', 'Drug Trafficking']
# ['False Claims Act', 'Health Care Fraud']
# ['Firearms Offenses', 'Violent Crime']
# ['Violent Crime']
# ['Violent Crime']
# ['Violent Crime']
# ['Grants']
# ['Hate Crimes']
# ['Cyber Crime']
# ['Asset Forfeiture', 'Foreign Corruption', 'Public Corruption']
# ['Environment']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Public Corruption']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Tax']
# ['False Claims Act']
# ['Tax']
# ['Tax']
# ['Tax']
# ['Counterintelligence and Export Control']
# ['Counterterrorism']
# ['Hate Crimes', 'Civil Rights']
# ['Counterterrorism']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Civil Rights', 'Hate Crimes']
# ['Human Trafficking', 'Project Safe Childhood']
# ['Counterterrorism', 'National Security']
# ['Hate Crimes']
# ['Project Safe Childhood']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism', 'National Security']
# ['Tax']
# ['Project Safe Childhood']
# ['Identity Theft', 'Tax']
# ['Consumer Protection']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Counterterrorism']
# ['Human Trafficking', 'Project Safe Childhood']
# ['Counterterrorism']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Human Trafficking', 'Project Safe Childhood']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Counterterrorism']
# ['Project Safe Childhood']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Consumer Protection']
# ['Project Safe Childhood']
# ['Project Safe Childhood']
# ['Tax']
# ['StopFraud']
# ['Consumer Protection']
# ['Environment', 'Wildlife']
# ['Tax']
# ['Consumer Protection']
# ['Tax']
# ['Intellectual Property']
# ['Intellectual Property']
# ['Tax']
# ['Tax']
# ['Hate Crimes']
# ['Identity Theft', 'Tax']
# ['Identity Theft', 'Tax']
# ['Intellectual Property']
# ['Tax']
# ['False Claims Act']
# ['Environment', 'StopFraud']
# ['Environment', 'Securities, Commodities, & Investment Fraud']
# ['Environment']
# ['Environment']
# ['Environment']
# ['Consumer Protection', 'Environment']
# ['StopFraud']
# ['Antitrust']
# ['False Claims Act', 'Mortgage Fraud']
# ['Consumer Protection', 'False Claims Act', 'Health Care Fraud']
# ['Tax']
# ['Tax']
# ['Identity Theft', 'Tax']
# ['Tax']
# ['Public Corruption']
# ['Antitrust']
# ['Hate Crimes']
# ['Hate Crimes']
# ['False Claims Act']
# ['Tax']
# ['Tax']
# ['Hate Crimes']
# ['Antitrust']
# ['Public Corruption']
# ['False Claims Act']
# ['Tax']
# ['Tax']
# ['StopFraud', 'Tax']
# ['Tax']
# ['Tax']
# ['Hate Crimes']
# ['False Claims Act']
# ['Asset Forfeiture']
# ['Access to Justice']
# ['Access to Justice']
# ['Violent Crime']
# ['Counterterrorism', 'National Security']
# ['Counterterrorism']
# ['Firearms Offenses', 'Violent Crime']
# ['Environment', 'Wildlife']
# ['False Claims Act']
# ['False Claims Act']
# ['Project Safe Childhood']
# ['Counterterrorism', 'National Security']
# ['Project Safe Childhood']
# ['Counterterrorism']
# ['Civil Rights', 'Human Trafficking']
# ['Tax']
# ['Counterterrorism']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection']
# ['Consumer Protection', 'Elder Justice']
# ['Civil Rights', 'Human Trafficking']
# ['Antitrust']
# ['False Claims Act', 'Health Care Fraud']
# ['Consumer Protection']
# ['Civil Rights']
# ['Environment']
# ['Antitrust']
# ['Counterterrorism']
# ['Cyber Crime']
# ['Hate Crimes']
# ['Environment']
# ['Foreign Corruption']
# ['Asset Forfeiture', 'Counterintelligence and Export Control']
# ['Counterintelligence and Export Control']

# %%
# Out:
# [['Environment']]
# [['Consumer Protection']]
# [['Environment']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Health Care Fraud', 'False Claims Act']]
# [['Consumer Protection', 'Elder Justice']]
# [['Consumer Protection', 'StopFraud']]
# [['Opioids']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Drug Trafficking', 'Indian Country Law and Justice']]
# [['False Claims Act']]
# [['Drug Trafficking']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Tax']]
# [['Health Care Fraud']]
# [['Drug Trafficking', 'Opioids']]
# [['Asset Forfeiture', 'Tax']]
# [['Public Corruption']]
# [['Civil Rights', 'Human Trafficking']]
# [['Civil Rights']]
# [['Violent Crime']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud', 'StopFraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Tax']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['Antitrust']]
# [['Counterterrorism']]
# [['Antitrust']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Project Safe Childhood']]
# [['Identity Theft', 'Tax']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Hate Crimes']]
# [['Counterterrorism']]
# [['Hate Crimes']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Tax']]
# [['Hate Crimes']]
# [['Counterterrorism']]
# [['Project Safe Childhood']]
# [['Hate Crimes']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Opioids', 'Prescription Drugs', 'Health Care Fraud']]
# [['Antitrust', 'StopFraud']]
# [['StopFraud']]
# [['StopFraud']]
# [['StopFraud']]
# [['StopFraud']]
# [['StopFraud']]
# [['Antitrust', 'StopFraud']]
# [['Antitrust']]
# [['StopFraud']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['False Claims Act']]
# [['Counterintelligence and Export Control']]
# [['Project Safe Childhood']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Project Safe Childhood']]
# [['Hate Crimes']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Drug Trafficking']]
# [['Drug Trafficking']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['Financial Fraud']]
# [['Wildlife']]
# [['Counterterrorism']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Counterterrorism', 'National Security']]
# [['False Claims Act']]
# [['StopFraud']]
# [['Antitrust']]
# [['Opioids', 'Cyber Crime', 'Drug Trafficking']]
# [['Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Antitrust']]
# [['Counterterrorism']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism']]
# [['National Security']]
# [['Wildlife']]
# [['Counterterrorism']]
# [['Consumer Protection']]
# [['Access to Justice']]
# [['Civil Rights']]
# [['Environment']]
# [['Consumer Protection']]
# [['Wildlife']]
# [['Wildlife']]
# [['Antitrust', 'Office and Personnel Updates']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Consumer Protection']]
# [['False Claims Act', 'Financial Fraud']]
# [['Hate Crimes']]
# [['Antitrust']]
# [['Office and Personnel Updates']]
# [['Violent Crime']]
# [['Indian Country Law and Justice']]
# [['Project Safe Childhood']]
# [['Counterterrorism']]
# [['Cyber Crime']]
# [['Intellectual Property']]
# [['Indian Country Law and Justice']]
# [['Bankruptcy', 'Financial Fraud']]
# [['Tax']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Counterintelligence and Export Control']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Cyber Crime']]
# [['Tax']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Public Corruption']]
# [['Financial Fraud']]
# [['Hate Crimes']]
# [['National Security']]
# [['Hate Crimes']]
# [['Public Corruption']]
# [['Project Safe Childhood']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Indian Country Law and Justice']]
# [['Civil Rights']]
# [['Financial Fraud', 'Foreign Corruption']]
# [['Financial Fraud']]
# [['Hate Crimes']]
# [['Drug Trafficking']]
# [['Drug Trafficking', 'Violent Crime']]
# [['Health Care Fraud']]
# [['Environment']]
# [['Antitrust']]
# [['Indian Country Law and Justice']]
# [['Indian Country Law and Justice']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['Civil Rights', 'Violent Crime']]
# [['StopFraud']]
# [['Cyber Crime', 'Securities, Commodities, & Investment Fraud']]
# [['Violent Crime']]
# [['Indian Country Law and Justice']]
# [['Immigration']]
# [['Consumer Protection']]
# [['Intellectual Property']]
# [['Consumer Protection']]
# [['Project Safe Childhood']]
# [['Consumer Protection', 'StopFraud']]
# [['Indian Country Law and Justice']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Indian Country Law and Justice']]
# [['Indian Country Law and Justice']]
# [['Access to Justice']]
# [['National Security']]
# [['Indian Country Law and Justice']]
# [['Indian Country Law and Justice']]
# [['Access to Justice']]
# [['Access to Justice']]
# [['Consumer Protection']]
# [['Indian Country Law and Justice']]
# [['Access to Justice']]
# [['Indian Country Law and Justice']]
# [['Access to Justice']]
# [['Indian Country Law and Justice']]
# [['Access to Justice']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Indian Country Law and Justice']]
# [['Access to Justice']]
# [['Access to Justice']]
# [['Consumer Protection']]
# [['Civil Rights']]
# [['Office and Personnel Updates']]
# [['Office and Personnel Updates']]
# [['Immigration']]
# [['Drug Trafficking', 'Opioids']]
# [['Indian Country Law and Justice']]
# [['Violent Crime']]
# [['Opioids']]
# [['Office and Personnel Updates']]
# [['Human Trafficking']]
# [['Opioids']]
# [['Bankruptcy', 'Office and Personnel Updates']]
# [['Counterterrorism']]
# [['Violent Crime', 'Firearms Offenses']]
# [['Immigration']]
# [['Hate Crimes']]
# [['Asset Forfeiture']]
# [['Violent Crime']]
# [['Office and Personnel Updates']]
# [['Office and Personnel Updates']]
# [['Antitrust']]
# [['Indian Country Law and Justice']]
# [['Human Trafficking']]
# [['Grants']]
# [['Civil Rights', 'Human Trafficking']]
# [['Human Trafficking']]
# [['Human Trafficking']]
# [['Grants', 'Indian Country Law and Justice']]
# [['Antitrust']]
# [['Opioids']]
# [['Community Outreach']]
# [['Hate Crimes']]
# [['Environment']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Office and Personnel Updates']]
# [['Community Outreach']]
# [['Grants', 'Human Trafficking']]
# [['Consumer Protection']]
# [['Community Outreach']]
# [['Office and Personnel Updates']]
# [['Drug Trafficking', 'Grants']]
# [['Violent Crime']]
# [['Prescription Drugs']]
# [['Violent Crime']]
# [['Prescription Drugs']]
# [['Asset Forfeiture']]
# [['Prescription Drugs']]
# [['Counterterrorism']]
# [['Grants', 'Immigration']]
# [['Cyber Crime']]
# [['Opioids', 'Prescription Drugs']]
# [['Drug Trafficking']]
# [['Opioids', 'Drug Trafficking']]
# [['Cyber Crime']]
# [['Opioids', 'Office and Personnel Updates']]
# [['Drug Trafficking']]
# [['National Security']]
# [['Violent Crime']]
# [['Immigration']]
# [['Drug Trafficking', 'Opioids', 'Prescription Drugs']]
# [['Asset Forfeiture', 'Opioids']]
# [['National Security']]
# [['Drug Trafficking']]
# [['Drug Trafficking']]
# [['Immigration']]
# [['Immigration']]
# [['Prescription Drugs']]
# [['Cyber Crime']]
# [['Wildlife']]
# [['Counterterrorism', 'National Security']]
# [['StopFraud']]
# [['Consumer Protection', 'Disaster Fraud', 'Financial Fraud']]
# [['Intellectual Property']]
# [['Antitrust']]
# [['Antitrust']]
# [['Cyber Crime']]
# [['StopFraud']]
# [['Consumer Protection']]
# [['Financial Fraud', 'Project Safe Childhood']]
# [['Hate Crimes']]
# [['Drug Trafficking', 'Public Corruption', 'Tax']]
# [['Civil Rights', 'Hate Crimes']]
# [['Civil Rights']]
# [['Tax']]
# [['Antitrust']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Financial Fraud', 'Mortgage Fraud']]
# [['StopFraud']]
# [['Drug Trafficking']]
# [['Opioids', 'Violent Crime', 'Drug Trafficking']]
# [['Opioids', 'Violent Crime', 'Drug Trafficking']]
# [['Drug Trafficking']]
# [['Environment']]
# [['False Claims Act']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Disaster Fraud']]
# [['Consumer Protection', 'False Claims Act', 'Health Care Fraud']]
# [['Antitrust']]
# [['False Claims Act']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act']]
# [['Wildlife']]
# [['Wildlife']]
# [['Health Care Fraud']]
# [['Environment']]
# [['Consumer Protection']]
# [['Labor & Employment', 'Environment']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Antitrust']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['Immigration']]
# [['Civil Rights']]
# [['False Claims Act']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Civil Rights', 'Hate Crimes']]
# [['Project Safe Childhood']]
# [['StopFraud']]
# [['Consumer Protection', 'Identity Theft']]
# [['Project Safe Childhood']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Wildlife']]
# [['Consumer Protection']]
# [['Counterterrorism', 'National Security']]
# [['Counterintelligence and Export Control']]
# [['Environment', 'Wildlife']]
# [['Tax']]
# [['National Security']]
# [['Tax']]
# [['Tax']]
# [['Cyber Crime']]
# [['Public Corruption']]
# [['Counterintelligence and Export Control']]
# [['Antitrust']]
# [['Antitrust']]
# [['Indian Country Law and Justice']]
# [['Foreign Corruption', 'Tax']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['Antitrust']]
# [['Environment', 'Wildlife']]
# [['False Claims Act']]
# [['Tax']]
# [['Tax']]
# [['Mortgage Fraud', 'Tax']]
# [['Mortgage Fraud', 'Tax']]
# [['Health Care Fraud', 'StopFraud']]
# [['Hate Crimes']]
# [['Health Care Fraud']]
# [['Tax']]
# [['Consumer Protection']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Civil Rights', 'Human Trafficking']]
# [['Tax']]
# [['Counterterrorism']]
# [['Counterintelligence and Export Control']]
# [['National Security']]
# [['Counterterrorism']]
# [['Counterterrorism', 'National Security']]
# [['Financial Fraud']]
# [['Drug Trafficking']]
# [['Project Safe Childhood']]
# [['Hate Crimes']]
# [['Identity Theft', 'Tax']]
# [['Counterterrorism']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism']]
# [['Project Safe Childhood']]
# [['Consumer Protection']]
# [['Firearms Offenses']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism']]
# [['Identity Theft', 'Tax']]
# [['Counterintelligence and Export Control']]
# [['Financial Fraud', 'Tax']]
# [['Tax']]
# [['Financial Fraud', 'StopFraud']]
# [['Consumer Protection']]
# [['Project Safe Childhood']]
# [['Identity Theft', 'Tax']]
# [['Project Safe Childhood']]
# [['Counterterrorism', 'National Security']]
# [['Project Safe Childhood']]
# [['Wildlife']]
# [['Counterterrorism', 'Financial Fraud', 'National Security']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Environment']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Project Safe Childhood']]
# [['Hate Crimes']]
# [['Firearms Offenses', 'Violent Crime']]
# [['Wildlife']]
# [['Project Safe Childhood']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Consumer Protection']]
# [['Intellectual Property']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Intellectual Property']]
# [['Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['Consumer Protection', 'Financial Fraud']]
# [['Identity Theft', 'Tax']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Counterintelligence and Export Control']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['Financial Fraud', 'StopFraud']]
# [['Counterintelligence and Export Control']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Public Corruption']]
# [['Wildlife']]
# [['Wildlife']]
# [['Environment', 'Wildlife']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Antitrust']]
# [['Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Counterterrorism']]
# [['Tax']]
# [['Environment', 'Wildlife']]
# [['Tax']]
# [['False Claims Act', 'Tax']]
# [['Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Drug Trafficking']]
# [['False Claims Act']]
# [['Tax']]
# [['Intellectual Property']]
# [['StopFraud']]
# [['StopFraud']]
# [['Environment']]
# [['StopFraud']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Securities, Commodities, & Investment Fraud', 'Tax']]
# [['Securities, Commodities, & Investment Fraud', 'Tax']]
# [['Immigration']]
# [['Foreign Corruption']]
# [['Financial Fraud']]
# [['Tax']]
# [['Financial Fraud', 'Public Corruption', 'StopFraud', 'Tax']]
# [['Counterterrorism']]
# [['Health Care Fraud']]
# [['Hate Crimes']]
# [['Tax']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Hate Crimes']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Environment']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Tax']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['National Security']]
# [['Violent Crime']]
# [['Drug Trafficking']]
# [['Antitrust']]
# [['Consumer Protection']]
# [['StopFraud']]
# [['Financial Fraud']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Counterintelligence and Export Control']]
# [['Financial Fraud']]
# [['Antitrust']]
# [['Public Corruption']]
# [['False Claims Act']]
# [['Foreign Corruption']]
# [['Consumer Protection', 'Health Care Fraud']]
# [['Consumer Protection', 'Health Care Fraud']]
# [['Counterintelligence and Export Control']]
# [['National Security']]
# [['Intellectual Property']]
# [['Cyber Crime', 'National Security']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Counterintelligence and Export Control', 'Cyber Crime', 'National Security']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Intellectual Property']]
# [['Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control', 'Cyber Crime', 'National Security']]
# [['National Security']]
# [['Intellectual Property']]
# [['Intellectual Property']]
# [['Counterintelligence and Export Control']]
# [['False Claims Act']]
# [['Consumer Protection']]
# [['National Security']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism', 'National Security']]
# [['Human Trafficking']]
# [['Counterterrorism', 'National Security']]
# [['False Claims Act']]
# [['Tax']]
# [['Environment']]
# [['Consumer Protection']]
# [['Antitrust']]
# [['Health Care Fraud', 'StopFraud']]
# [['Health Care Fraud']]
# [['Intellectual Property']]
# [['Tax']]
# [['Consumer Protection']]
# [['Opioids']]
# [['Drug Trafficking', 'Immigration']]
# [['Drug Trafficking']]
# [['Drug Trafficking']]
# [['Drug Trafficking']]
# [['False Claims Act']]
# [['Project Safe Childhood']]
# [['Wildlife']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Indian Country Law and Justice']]
# [['Tax']]
# [['Project Safe Childhood']]
# [['Tax']]
# [['Tax']]
# [['StopFraud']]
# [['Tax']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism', 'National Security']]
# [['Hate Crimes']]
# [['Antitrust']]
# [['Consumer Protection']]
# [['False Claims Act']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Consumer Protection']]
# [['Environment']]
# [['Environment']]
# [['Counterintelligence and Export Control', 'Cyber Crime', 'National Security']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Public Corruption']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Environment', 'Wildlife']]
# [['StopFraud']]
# [['Tax']]
# [['Tax']]
# [['Cyber Crime', 'Intellectual Property']]
# [['Antitrust']]
# [['Antitrust']]
# [['Environment']]
# [['Antitrust']]
# [['Asset Forfeiture', 'Counterintelligence and Export Control']]
# [['Antitrust']]
# [['Violent Crime']]
# [['Tax']]
# [['Project Safe Childhood']]
# [['Antitrust']]
# [['Antitrust']]
# [['Opioids', 'Prescription Drugs']]
# [['National Security']]
# [['Environment']]
# [['Consumer Protection']]
# [['Civil Rights']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['Tax']]
# [['Cyber Crime']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['False Claims Act']]
# [['National Security']]
# [['Tax']]
# [['Consumer Protection']]
# [['Financial Fraud', 'Mortgage Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Tax']]
# [['Tax']]
# [['Cyber Crime', 'Intellectual Property']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Environment']]
# [['Civil Rights']]
# [['Antitrust']]
# [['Cyber Crime']]
# [['Cyber Crime']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud', 'False Claims Act']]
# [['Consumer Protection']]
# [['Project Safe Childhood']]
# [['Cyber Crime']]
# [['False Claims Act']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Antitrust']]
# [['Tax']]
# [['Tax']]
# [['Prescription Drugs']]
# [['Opioids']]
# [['Prescription Drugs']]
# [['Prescription Drugs']]
# [['Opioids', 'Prescription Drugs']]
# [['Antitrust']]
# [['Violent Crime']]
# [['Counterterrorism']]
# [['Indian Country Law and Justice']]
# [['Cyber Crime']]
# [['Counterterrorism']]
# [['Identity Theft']]
# [['Indian Country Law and Justice', 'Violent Crime']]
# [['Consumer Protection', 'Elder Justice']]
# [['Counterterrorism', 'National Security']]
# [['Intellectual Property']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['False Claims Act', 'Financial Fraud']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Counterintelligence and Export Control']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['Civil Rights']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Environment', 'Wildlife']]
# [['False Claims Act', 'StopFraud']]
# [['False Claims Act']]
# [['Immigration']]
# [['Immigration']]
# [['Immigration']]
# [['Immigration']]
# [['Health Care Fraud']]
# [['Drug Trafficking']]
# [['Consumer Protection']]
# [['Access to Justice']]
# [['Health Care Fraud']]
# [['Environment']]
# [['Environment']]
# [['Environment']]
# [['Environment']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Health Care Fraud']]
# [['Office and Personnel Updates']]
# [['Antitrust']]
# [['Asset Forfeiture', 'Wildlife']]
# [['Indian Country Law and Justice']]
# [['Prescription Drugs', 'Indian Country Law and Justice']]
# [['Indian Country Law and Justice']]
# [['Indian Country Law and Justice']]
# [['Indian Country Law and Justice']]
# [['Antitrust']]
# [['Office and Personnel Updates']]
# [['Opioids']]
# [['Intellectual Property']]
# [['Community Outreach']]
# [['Immigration']]
# [['Access to Justice']]
# [['Civil Rights']]
# [['Indian Country Law and Justice']]
# [['Tax']]
# [['Drug Trafficking', 'Opioids', 'Prescription Drugs']]
# [['Grants']]
# [['Indian Country Law and Justice']]
# [['Office and Personnel Updates']]
# [['Grants']]
# [['Grants']]
# [['Grants']]
# [['Grants', 'Human Trafficking']]
# [['Opioids', 'Prescription Drugs']]
# [['Grants']]
# [['Asset Forfeiture']]
# [['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'Health Care Fraud']]
# [['Asset Forfeiture']]
# [['Environment']]
# [['Environment']]
# [['Environment']]
# [['Access to Justice', 'Civil Rights']]
# [['Civil Rights']]
# [['Access to Justice', 'Civil Rights']]
# [['Consumer Protection']]
# [['Immigration']]
# [['Consumer Protection']]
# [['Immigration', 'National Security']]
# [['Environment']]
# [['Access to Justice']]
# [['Civil Rights']]
# [['Access to Justice']]
# [['Immigration']]
# [['Civil Rights']]
# [['Consumer Protection']]
# [['Servicemembers Initiative']]
# [['Civil Rights']]
# [['Elder Justice']]
# [['Office and Personnel Updates']]
# [['Opioids', 'Office and Personnel Updates']]
# [['Opioids', 'Immigration', 'Violent Crime']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Intellectual Property']]
# [['Opioids']]
# [['Elder Justice', 'Office and Personnel Updates']]
# [['Servicemembers Initiative']]
# [['Consumer Protection', 'Elder Justice', 'Financial Fraud']]
# [['Civil Rights']]
# [['Indian Country Law and Justice']]
# [['Indian Country Law and Justice']]
# [['StopFraud']]
# [['Asset Forfeiture']]
# [['Project Safe Childhood']]
# [['Indian Country Law and Justice']]
# [['Opioids', 'Prescription Drugs', 'Drug Trafficking']]
# [['Immigration']]
# [['Antitrust']]
# [['Asset Forfeiture', 'Foreign Corruption']]
# [['Antitrust']]
# [['Intellectual Property']]
# [['Servicemembers Initiative']]
# [['Antitrust']]
# [['Immigration']]
# [['Access to Justice']]
# [['StopFraud']]
# [['Antitrust']]
# [['Antitrust']]
# [['Civil Rights']]
# [['Health Care Fraud']]
# [['Consumer Protection']]
# [['Civil Rights']]
# [['Civil Rights', 'Immigration']]
# [['Immigration']]
# [['Immigration']]
# [['Access to Justice']]
# [['Grants']]
# [['Civil Rights']]
# [['Human Trafficking']]
# [['Grants']]
# [['Human Trafficking']]
# [['Foreign Corruption']]
# [['Project Safe Neighborhoods']]
# [['Asset Forfeiture']]
# [['Tax']]
# [['Tax']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud', 'StopFraud']]
# [['Health Care Fraud']]
# [['Environment']]
# [['Health Care Fraud']]
# [['Violent Crime']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Health Care Fraud', 'StopFraud']]
# [['Tax']]
# [['Financial Fraud', 'Mortgage Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Financial Fraud', 'Securities, Commodities, & Investment Fraud']]
# [['Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Consumer Protection']]
# [['Disaster Fraud']]
# [['Foreign Corruption']]
# [['Environment']]
# [['Environment']]
# [['Identity Theft', 'Tax']]
# [['Environment']]
# [['Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection', 'Health Care Fraud']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection', 'Health Care Fraud']]
# [['Consumer Protection', 'Health Care Fraud']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection', 'Elder Justice']]
# [['Consumer Protection']]
# [['Consumer Protection', 'Health Care Fraud']]
# [['Consumer Protection', 'Health Care Fraud']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection', 'Elder Justice']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Identity Theft']]
# [['Antitrust']]
# [['Antitrust', 'Intellectual Property']]
# [['Antitrust']]
# [['Antitrust']]
# [['Immigration']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Opioids']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['Health Care Fraud']]
# [['Consumer Protection', 'Elder Justice']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Environment']]
# [['False Claims Act']]
# [['Antitrust']]
# [['Antitrust']]
# [['Firearms Offenses', 'Violent Crime']]
# [['StopFraud']]
# [['Environment', 'Tax']]
# [['False Claims Act']]
# [['Cyber Crime']]
# [['Drug Trafficking']]
# [['Elder Justice']]
# [['Health Care Fraud']]
# [['Violent Crime']]
# [['Health Care Fraud', 'Identity Theft']]
# [['Financial Fraud', 'Securities, Commodities, & Investment Fraud']]
# [['Health Care Fraud']]
# [['Civil Rights', 'Human Trafficking']]
# [['Firearms Offenses', 'Violent Crime']]
# [['Violent Crime']]
# [['Firearms Offenses', 'Violent Crime']]
# [['StopFraud']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Antitrust']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Drug Trafficking', 'Violent Crime']]
# [['Intellectual Property']]
# [['Counterintelligence and Export Control']]
# [['Antitrust', 'StopFraud']]
# [['Counterterrorism']]
# [['Consumer Protection']]
# [['Antitrust']]
# [['Foreign Corruption']]
# [['Tax']]
# [['Environment']]
# [['Tax']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['False Claims Act']]
# [['Environment']]
# [['Antitrust']]
# [['Environment']]
# [['Environment']]
# [['Environment', 'Wildlife']]
# [['Tax']]
# [['Antitrust', 'StopFraud']]
# [['Counterterrorism']]
# [['Antitrust']]
# [['Immigration']]
# [['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Counterintelligence and Export Control']]
# [['Environment']]
# [['Health Care Fraud']]
# [['Hate Crimes']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Consumer Protection']]
# [['Tax']]
# [['Antitrust']]
# [['Opioids', 'Drug Trafficking']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Violent Crime']]
# [['Tax']]
# [['Tax']]
# [['Access to Justice', 'Consumer Protection']]
# [['Consumer Protection']]
# [['Indian Country Law and Justice']]
# [['Civil Rights']]
# [['Consumer Protection', 'StopFraud']]
# [['Environment']]
# [['Indian Country Law and Justice']]
# [['Hate Crimes']]
# [['False Claims Act']]
# [['Servicemembers Initiative']]
# [['Consumer Protection']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Civil Rights']]
# [['Consumer Protection']]
# [['Tax']]
# [['Consumer Protection']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Civil Rights']]
# [['Intellectual Property']]
# [['Intellectual Property']]
# [['Consumer Protection']]
# [['Consumer Protection', 'StopFraud']]
# [['Consumer Protection']]
# [['Counterintelligence and Export Control']]
# [['Tax']]
# [['Tax']]
# [['Drug Trafficking']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism', 'National Security']]
# [['Firearms Offenses']]
# [['Violent Crime']]
# [['Civil Rights', 'Hate Crimes']]
# [['Project Safe Childhood']]
# [['Violent Crime']]
# [['Counterterrorism', 'National Security']]
# [['Civil Rights']]
# [['Violent Crime']]
# [['Civil Rights']]
# [['Wildlife']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Environment']]
# [['Consumer Protection']]
# [['Intellectual Property']]
# [['Opioids', 'Drug Trafficking', 'Firearms Offenses']]
# [['False Claims Act', 'Health Care Fraud', 'StopFraud']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Hate Crimes']]
# [['Consumer Protection']]
# [['Project Safe Childhood']]
# [['Hate Crimes']]
# [['StopFraud']]
# [['False Claims Act', 'Financial Fraud', 'Mortgage Fraud']]
# [['Antitrust']]
# [['Antitrust']]
# [['Consumer Protection', 'Elder Justice']]
# [['Consumer Protection']]
# [['Drug Trafficking', 'Prescription Drugs', 'Violent Crime']]
# [['Indian Country Law and Justice']]
# [['False Claims Act']]
# [['Cyber Crime']]
# [['Opioids']]
# [['Environment']]
# [['Environment']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Hate Crimes']]
# [['Foreign Corruption']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Consumer Protection']]
# [['Health Care Fraud']]
# [['Tax']]
# [['Violent Crime']]
# [['Environment', 'Wildlife']]
# [['Antitrust']]
# [['Antitrust']]
# [['StopFraud', 'Antitrust']]
# [['Opioids', 'Health Care Fraud']]
# [['Environment']]
# [['Antitrust']]
# [['Antitrust']]
# [['Tax']]
# [['Tax']]
# [['Public Corruption']]
# [['Health Care Fraud', 'StopFraud']]
# [['False Claims Act']]
# [['StopFraud']]
# [['StopFraud']]
# [['Tax']]
# [['Financial Fraud']]
# [['Tax']]
# [['False Claims Act', 'Health Care Fraud', 'StopFraud']]
# [['False Claims Act']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Consumer Protection']]
# [['Health Care Fraud']]
# [['Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Financial Fraud']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['National Security']]
# [['Counterterrorism', 'National Security']]
# [['National Security']]
# [['Project Safe Childhood']]
# [['Civil Rights', 'Human Trafficking']]
# [['Counterterrorism']]
# [['Hate Crimes']]
# [['Civil Rights', 'Human Trafficking']]
# [['Tax']]
# [['Tax']]
# [['Project Safe Childhood']]
# [['Civil Rights', 'Human Trafficking']]
# [['Public Corruption']]
# [['Counterintelligence and Export Control']]
# [['Counterterrorism']]
# [['Asset Forfeiture', 'Cyber Crime']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Civil Rights', 'Hate Crimes']]
# [['Hate Crimes']]
# [['Public Corruption']]
# [['Tax']]
# [['Consumer Protection']]
# [['Identity Theft']]
# [['Civil Rights', 'Human Trafficking']]
# [['Project Safe Childhood']]
# [['Counterterrorism']]
# [['Civil Rights', 'Human Trafficking']]
# [['National Security']]
# [['StopFraud']]
# [['Counterintelligence and Export Control']]
# [['Intellectual Property']]
# [['Cyber Crime', 'Identity Theft']]
# [['Health Care Fraud', 'StopFraud']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Civil Rights']]
# [['Civil Rights', 'Human Trafficking']]
# [['Civil Rights', 'Hate Crimes']]
# [['Consumer Protection']]
# [['Hate Crimes']]
# [['Consumer Protection']]
# [['Civil Rights', 'Counterterrorism', 'National Security']]
# [['Identity Theft', 'Tax']]
# [['Consumer Protection']]
# [['Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Counterterrorism']]
# [['Tax']]
# [['Tax']]
# [['Tax', 'Identity Theft']]
# [['Tax']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['False Claims Act']]
# [['Tax']]
# [['National Security']]
# [['National Security']]
# [['Project Safe Childhood']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Tax']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['National Security']]
# [['Antitrust']]
# [['Human Trafficking']]
# [['Human Smuggling', 'Immigration']]
# [['Human Smuggling']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Project Safe Childhood']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Tax']]
# [['Civil Rights']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Foreign Corruption']]
# [['StopFraud']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['Tax']]
# [['Consumer Protection', 'Mortgage Fraud']]
# [['Environment']]
# [['Consumer Protection']]
# [['Antitrust']]
# [['Antitrust']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Immigration']]
# [['Civil Rights']]
# [['Financial Fraud']]
# [['Public Corruption']]
# [['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Financial Fraud']]
# [['Tax']]
# [['Public Corruption', 'Tax']]
# [['Wildlife']]
# [['Civil Rights']]
# [['Cyber Crime', 'Intellectual Property']]
# [['Civil Rights']]
# [['Project Safe Childhood']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Financial Fraud', 'StopFraud']]
# [['Financial Fraud']]
# [['Tax']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Financial Fraud']]
# [['Antitrust', 'StopFraud']]
# [['Antitrust']]
# [['Public Corruption']]
# [['Antitrust']]
# [['Financial Fraud']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Health Care Fraud']]
# [['Financial Fraud']]
# [['Environment', 'Financial Fraud']]
# [['StopFraud', 'Tax']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['StopFraud']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Financial Fraud']]
# [['Financial Fraud']]
# [['Securities, Commodities, & Investment Fraud']]
# [['StopFraud']]
# [['StopFraud']]
# [['Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Health Care Fraud']]
# [['Public Corruption']]
# [['Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control']]
# [['Public Corruption']]
# [['Project Safe Childhood']]
# [['Antitrust']]
# [['Antitrust']]
# [['Drug Trafficking']]
# [['Financial Fraud', 'Public Corruption']]
# [['National Security']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['StopFraud']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Financial Fraud']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Elder Justice', 'Public Corruption', 'Tax']]
# [['Public Corruption']]
# [['Tax']]
# [['Antitrust']]
# [['StopFraud']]
# [['StopFraud']]
# [['Public Corruption']]
# [['Counterintelligence and Export Control']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control']]
# [['Public Corruption']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['StopFraud']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Securities, Commodities, & Investment Fraud', 'Tax']]
# [['Tax']]
# [['Tax']]
# [['Antitrust']]
# [['Financial Fraud']]
# [['Project Safe Childhood']]
# [['Health Care Fraud']]
# [['Intellectual Property']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['StopFraud']]
# [['Public Corruption']]
# [['Financial Fraud']]
# [['Consumer Protection', 'StopFraud']]
# [['Tax']]
# [['Tax']]
# [['Antitrust']]
# [['Antitrust']]
# [['Public Corruption']]
# [['Tax']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['StopFraud']]
# [['StopFraud']]
# [['Antitrust']]
# [['StopFraud']]
# [['Financial Fraud']]
# [['Public Corruption']]
# [['Health Care Fraud']]
# [['Financial Fraud']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Counterintelligence and Export Control']]
# [['Public Corruption']]
# [['StopFraud']]
# [['False Claims Act']]
# [['StopFraud']]
# [['Public Corruption']]
# [['Tax']]
# [['Human Smuggling', 'Immigration', 'Violent Crime']]
# [['Human Smuggling', 'Violent Crime']]
# [['Health Care Fraud', 'StopFraud']]
# [['Health Care Fraud']]
# [['Tax']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Financial Fraud', 'Foreign Corruption', 'Public Corruption']]
# [['Financial Fraud', 'Foreign Corruption']]
# [['Foreign Corruption']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Financial Fraud']]
# [['Financial Fraud']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Tax']]
# [['Health Care Fraud']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Hate Crimes']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Public Corruption']]
# [['StopFraud', 'Tax']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Consumer Protection']]
# [['StopFraud']]
# [['Financial Fraud']]
# [['Public Corruption', 'Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Cyber Crime']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Public Corruption']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Identity Theft', 'Public Corruption']]
# [['Tax']]
# [['Tax']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Tax']]
# [['Civil Rights']]
# [['Tax']]
# [['Tax']]
# [['Drug Trafficking']]
# [['Public Corruption']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Project Safe Childhood']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Securities, Commodities, & Investment Fraud', 'Tax']]
# [['Civil Rights']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Public Corruption']]
# [['Antitrust']]
# [['Antitrust']]
# [['Immigration']]
# [['Public Corruption', 'Tax']]
# [['Civil Rights']]
# [['Tax']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Antitrust']]
# [['Project Safe Childhood']]
# [['Civil Rights']]
# [['Antitrust']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Financial Fraud', 'StopFraud']]
# [['StopFraud', 'Tax']]
# [['Public Corruption']]
# [['Tax']]
# [['Public Corruption']]
# [['Counterterrorism', 'National Security']]
# [['Project Safe Childhood']]
# [['Tax']]
# [['StopFraud']]
# [['Tax']]
# [['Tax']]
# [['Counterintelligence and Export Control']]
# [['Opioids', 'Public Corruption', 'Drug Trafficking']]
# [['Opioids', 'Public Corruption']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['StopFraud']]
# [['StopFraud']]
# [['Consumer Protection']]
# [['Public Corruption']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Tax']]
# [['Tax']]
# [['Consumer Protection', 'False Claims Act']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Foreign Corruption']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Foreign Corruption']]
# [['National Security']]
# [['National Security']]
# [['Health Care Fraud']]
# [['Financial Fraud', 'StopFraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Health Care Fraud']]
# [['Tax']]
# [['Tax']]
# [['Tax', 'Health Care Fraud']]
# [['Antitrust']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Prescription Drugs', 'Consumer Protection', 'Health Care Fraud']]
# [['Counterterrorism']]
# [['Tax']]
# [['Financial Fraud']]
# [['Tax']]
# [['Antitrust']]
# [['Financial Fraud']]
# [['Foreign Corruption']]
# [['Tax']]
# [['Health Care Fraud']]
# [['Civil Rights', 'Firearms Offenses']]
# [['Public Corruption']]
# [['Financial Fraud']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Antitrust', 'Financial Fraud', 'Securities, Commodities, & Investment Fraud']]
# [['Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Antitrust']]
# [['StopFraud']]
# [['False Claims Act']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Cyber Crime']]
# [['Public Corruption']]
# [['Financial Fraud', 'Public Corruption']]
# [['Financial Fraud']]
# [['Civil Rights']]
# [['Public Corruption']]
# [['Financial Fraud', 'Foreign Corruption']]
# [['Financial Fraud']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Identity Theft', 'Tax']]
# [['Cyber Crime', 'Intellectual Property']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Cyber Crime']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Financial Fraud']]
# [['Public Corruption']]
# [['Public Corruption', 'StopFraud']]
# [['Civil Rights']]
# [['Environment']]
# [['Environment']]
# [['Tax']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Identity Theft', 'Tax']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Tax']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Antitrust']]
# [['Antitrust']]
# [['Hate Crimes']]
# [['Civil Rights']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Tax']]
# [['Tax']]
# [['National Security']]
# [['Project Safe Childhood']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Tax']]
# [['Project Safe Childhood']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Cyber Crime']]
# [['Public Corruption']]
# [['Project Safe Childhood']]
# [['Counterintelligence and Export Control', 'Cyber Crime', 'National Security']]
# [['National Security']]
# [['Project Safe Childhood']]
# [['Cyber Crime']]
# [['Cyber Crime', 'Intellectual Property']]
# [['Tax']]
# [['Financial Fraud']]
# [['Financial Fraud', 'Public Corruption']]
# [['Environment']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Financial Fraud']]
# [['Public Corruption']]
# [['Cyber Crime']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Tax']]
# [['Tax']]
# [['Financial Fraud']]
# [['StopFraud']]
# [['Tax']]
# [['Tax']]
# [['Environment']]
# [['Project Safe Neighborhoods']]
# [['Opioids']]
# [['Cyber Crime']]
# [['Intellectual Property']]
# [['Opioids']]
# [['Intellectual Property']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Indian Country Law and Justice']]
# [['Foreign Corruption']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Asset Forfeiture', 'Counterintelligence and Export Control', 'National Security']]
# [['National Security']]
# [['Identity Theft', 'Tax']]
# [['Health Care Fraud']]
# [['Civil Rights']]
# [['Public Corruption']]
# [['Intellectual Property']]
# [['Hate Crimes']]
# [['Drug Trafficking']]
# [['Hate Crimes']]
# [['Tax']]
# [['Environment', 'Wildlife']]
# [['Counterterrorism', 'National Security']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Violent Crime', 'Firearms Offenses']]
# [['Firearms Offenses', 'Violent Crime']]
# [['StopFraud']]
# [['Antitrust']]
# [['Drug Trafficking', 'Violent Crime']]
# [['Drug Trafficking', 'Firearms Offenses', 'Violent Crime']]
# [['False Claims Act']]
# [['Tax']]
# [['Antitrust']]
# [['Antitrust']]
# [['Environment']]
# [['Civil Rights', 'Hate Crimes']]
# [['Disaster Fraud']]
# [['Drug Trafficking', 'Violent Crime']]
# [['Drug Trafficking']]
# [['Drug Trafficking', 'Public Corruption']]
# [['Counterterrorism', 'National Security']]
# [['Cyber Crime', 'Intellectual Property']]
# [['Civil Rights', 'Human Trafficking']]
# [['Civil Rights', 'Human Trafficking']]
# [['Antitrust', 'StopFraud', 'Tax']]
# [['StopFraud']]
# [['Cyber Crime']]
# [['Counterterrorism', 'National Security']]
# [['Antitrust']]
# [['Antitrust']]
# [['Hate Crimes']]
# [['False Claims Act']]
# [['Consumer Protection']]
# [['False Claims Act']]
# [['Project Safe Childhood']]
# [['Human Trafficking']]
# [['Tax']]
# [['Public Corruption', 'Health Care Fraud', 'Financial Fraud']]
# [['Financial Fraud']]
# [['Environment']]
# [['Financial Fraud']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Foreign Corruption']]
# [['Financial Fraud', 'Foreign Corruption']]
# [['Opioids', 'Health Care Fraud', 'False Claims Act']]
# [['Violent Crime']]
# [['Environment']]
# [['Environment']]
# [['StopFraud']]
# [['Financial Fraud', 'Foreign Corruption']]
# [['Environment']]
# [['Consumer Protection']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Consumer Protection', 'False Claims Act']]
# [['Tax']]
# [['StopFraud']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['Tax']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Tax']]
# [['Immigration']]
# [['Consumer Protection']]
# [['Identity Theft', 'Tax']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Immigration']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['StopFraud']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['StopFraud']]
# [['Antitrust']]
# [['Antitrust', 'Financial Fraud']]
# [['Antitrust']]
# [['Consumer Protection']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Consumer Protection', 'Elder Justice']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Environment']]
# [['Environment']]
# [['Environment']]
# [['False Claims Act']]
# [['Consumer Protection']]
# [['Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Consumer Protection']]
# [['Financial Fraud']]
# [['Consumer Protection']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Consumer Protection']]
# [['False Claims Act']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Project Safe Childhood']]
# [['Environment']]
# [['National Security']]
# [['Hate Crimes']]
# [['Antitrust']]
# [['Environment']]
# [['Civil Rights']]
# [['Antitrust']]
# [['Environment']]
# [['Hate Crimes', 'Human Trafficking', 'Violent Crime']]
# [['Asset Forfeiture']]
# [['Drug Trafficking']]
# [['Drug Trafficking']]
# [['Antitrust']]
# [['Counterterrorism', 'National Security']]
# [['Environment']]
# [['Counterterrorism', 'National Security']]
# [['Tax']]
# [['Counterterrorism']]
# [['Environment']]
# [['Environment']]
# [['False Claims Act']]
# [['Opioids', 'Health Care Fraud']]
# [['Health Care Fraud']]
# [['False Claims Act']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Antitrust']]
# [['Civil Rights', 'Drug Trafficking', 'Human Trafficking']]
# [['Drug Trafficking']]
# [['Public Corruption', 'StopFraud']]
# [['Environment']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['False Claims Act']]
# [['Health Care Fraud']]
# [['Health Care Fraud', 'StopFraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Financial Fraud']]
# [['Counterterrorism']]
# [['Public Corruption']]
# [['Violent Crime']]
# [['Counterterrorism']]
# [['Environment']]
# [['StopFraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud', 'StopFraud']]
# [['StopFraud']]
# [['Tax']]
# [['Health Care Fraud']]
# [['Tax']]
# [['Health Care Fraud']]
# [['StopFraud']]
# [['Identity Theft', 'Tax']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Environment', 'StopFraud']]
# [['Hate Crimes']]
# [['Counterterrorism']]
# [['Opioids', 'Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Human Trafficking']]
# [['Financial Fraud']]
# [['Human Trafficking']]
# [['Tax']]
# [['Health Care Fraud']]
# [['StopFraud']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['False Claims Act']]
# [['StopFraud']]
# [['Civil Rights']]
# [['Civil Rights', 'Hate Crimes']]
# [['Civil Rights', 'Hate Crimes']]
# [['Tax']]
# [['Tax']]
# [['Identity Theft']]
# [['Identity Theft']]
# [['Identity Theft', 'Tax']]
# [['Consumer Protection']]
# [['Human Trafficking', 'Project Safe Childhood']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Counterterrorism', 'National Security']]
# [['Project Safe Childhood']]
# [['Counterterrorism']]
# [['Tax']]
# [['Consumer Protection']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Identity Theft', 'Tax']]
# [['Human Trafficking', 'Project Safe Childhood']]
# [['Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Immigration']]
# [['False Claims Act']]
# [['Hate Crimes']]
# [['Human Trafficking']]
# [['Prescription Drugs']]
# [['Project Safe Childhood']]
# [['Counterterrorism', 'National Security']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Hate Crimes']]
# [['Tax']]
# [['Hate Crimes']]
# [['Counterterrorism']]
# [['Hate Crimes']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Hate Crimes']]
# [['Tax']]
# ...
# [['Hate Crimes']]
# [['Counterterrorism']]
# [['Wildlife']]
# [['Environment']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Health Care Fraud']]
# [['Counterintelligence and Export Control']]
# [['Counterterrorism']]
# [['Tax']]
# [['Civil Rights']]
# [['Consumer Protection']]
# [['Antitrust']]
# [['Counterterrorism']]
# [['Violent Crime']]
# [['Public Corruption']]
# [['StopFraud']]
# [['Cyber Crime', 'Financial Fraud', 'Identity Theft']]
# [['Cyber Crime', 'Financial Fraud']]
# [['StopFraud']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Hate Crimes']]
# [['Identity Theft', 'Tax']]
# [['Hate Crimes']]
# [['Financial Fraud']]
# [['Antitrust']]
# [['Cyber Crime', 'Identity Theft']]
# [['Hate Crimes']]
# [['Environment', 'Securities, Commodities, & Investment Fraud']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Violent Crime']]
# [['Hate Crimes']]
# [['Tax']]
# [['Tax']]
# [['Firearms Offenses', 'Violent Crime']]
# [['Environment', 'Wildlife']]
# [['Disaster Fraud']]
# [['Consumer Protection']]
# [['Environment']]
# [['Counterterrorism', 'National Security']]
# [['Environment']]
# [['Environment']]
# [['Environment']]
# [['Antitrust']]
# [['Counterterrorism', 'National Security']]
# [['Foreign Corruption']]
# [['Financial Fraud']]
# [['Public Corruption']]
# [['Wildlife']]
# [['Antitrust']]
# [['Environment']]
# [['Environment']]
# [['Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Environment']]
# [['Opioids', 'Violent Crime', 'Drug Trafficking']]
# [['Hate Crimes']]
# [['Identity Theft']]
# [['StopFraud']]
# [['Health Care Fraud']]
# [['Opioids', 'Violent Crime', 'Drug Trafficking']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Cyber Crime', 'National Security']]
# [['Violent Crime']]
# [['Human Trafficking', 'Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['StopFraud']]
# [['StopFraud']]
# [['Civil Rights', 'Human Trafficking']]
# [['Violent Crime']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Drug Trafficking', 'Violent Crime']]
# [['Hate Crimes']]
# [['Cyber Crime']]
# [['Hate Crimes']]
# [['Identity Theft', 'Tax']]
# [['Environment']]
# [['StopFraud', 'Tax']]
# [['Counterintelligence and Export Control']]
# [['Foreign Corruption']]
# [['Counterintelligence and Export Control']]
# [['Counterterrorism', 'National Security']]
# [['Hate Crimes']]
# [['Wildlife']]
# [['Consumer Protection', 'Mortgage Fraud']]
# [['StopFraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Violent Crime']]
# [['Tax']]
# [['Consumer Protection']]
# [['Financial Fraud']]
# [['Hate Crimes']]
# [['Securities, Commodities, & Investment Fraud']]
# [['False Claims Act']]
# [['Public Corruption']]
# [['Elder Justice']]
# [['Health Care Fraud']]
# [['National Security']]
# [['Civil Rights', 'Immigration']]
# [['Human Trafficking']]
# [['Consumer Protection', 'Elder Justice']]
# [['Human Trafficking']]
# [['Tax']]
# [['Public Corruption']]
# [['Consumer Protection', 'Prescription Drugs']]
# [['Antitrust']]
# [['Antitrust']]
# [['StopFraud']]
# [['Counterterrorism', 'National Security']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Counterterrorism']]
# [['Environment']]
# [['Environment']]
# [['Wildlife']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Financial Fraud']]
# [['Civil Rights']]
# [['Public Corruption']]
# [['Antitrust', 'Financial Fraud', 'StopFraud']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Public Corruption']]
# [['Public Corruption', 'StopFraud']]
# [['Civil Rights']]
# [['Antitrust', 'Securities, Commodities, & Investment Fraud']]
# [['StopFraud']]
# [['Antitrust', 'Financial Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Public Corruption']]
# [['Securities, Commodities, & Investment Fraud']]
# [['Civil Rights']]
# [['Antitrust']]
# [['Tax']]
# [['Antitrust']]
# [['Antitrust', 'Financial Fraud', 'StopFraud']]
# [['Antitrust']]
# [['Environment']]
# [['Human Trafficking']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Identity Theft']]
# [['Counterterrorism']]
# [['Identity Theft', 'Tax']]
# [['Violent Crime']]
# [['Hate Crimes']]
# [['False Claims Act']]
# [['Consumer Protection']]
# [['National Security']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Securities, Commodities, & Investment Fraud', 'Financial Fraud']]
# [['Environment']]
# [['Counterintelligence and Export Control']]
# [['Antitrust']]
# [['Antitrust']]
# [['Civil Rights', 'Hate Crimes']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['Human Trafficking']]
# [['Identity Theft', 'Tax']]
# [['Health Care Fraud', 'StopFraud']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Project Safe Childhood']]
# [['Identity Theft', 'Tax']]
# [['Counterterrorism']]
# [['Foreign Corruption']]
# [['Violent Crime']]
# [['Project Safe Childhood']]
# [['Counterintelligence and Export Control']]
# [['Counterterrorism']]
# [['Hate Crimes']]
# [['Tax']]
# [['Consumer Protection']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Consumer Protection']]
# [['Wildlife']]
# [['Environment']]
# [['Hate Crimes']]
# [['Identity Theft']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Counterterrorism', 'National Security']]
# [['Human Trafficking']]
# [['Identity Theft', 'Tax']]
# [['Health Care Fraud']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Intellectual Property']]
# [['Health Care Fraud']]
# [['Counterterrorism']]
# [['Tax']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['StopFraud', 'Antitrust']]
# [['Antitrust']]
# [['StopFraud']]
# [['Antitrust', 'StopFraud']]
# [['StopFraud']]
# [['Antitrust']]
# [['Tax']]
# [['Civil Rights', 'Hate Crimes']]
# [['Violent Crime']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Consumer Protection']]
# [['Consumer Protection', 'Prescription Drugs']]
# [['Tax']]
# [['Consumer Protection']]
# [['Health Care Fraud']]
# [['Consumer Protection']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Counterterrorism', 'National Security']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Cyber Crime']]
# [['Consumer Protection', 'Prescription Drugs']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Public Corruption']]
# [['StopFraud']]
# [['Violent Crime']]
# [['Hate Crimes']]
# [['Financial Fraud', 'Tax']]
# [['Tax']]
# [['Counterterrorism']]
# [['Environment']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Civil Rights', 'Hate Crimes']]
# [['Civil Rights']]
# [['Environment']]
# [['Counterterrorism']]
# [['Counterterrorism', 'National Security']]
# [['Hate Crimes']]
# [['Health Care Fraud', 'StopFraud']]
# [['Counterterrorism']]
# [['Counterterrorism', 'National Security']]
# [['Environment']]
# [['Environment']]
# [['Environment']]
# [['StopFraud']]
# [['Counterintelligence and Export Control', 'National Security']]
# [['Cyber Crime']]
# [['Antitrust']]
# [['Environment']]
# [['Environment']]
# [['Antitrust']]
# [['False Claims Act']]
# [['False Claims Act', 'Financial Fraud', 'Mortgage Fraud']]
# [['Indian Country Law and Justice']]
# [['Indian Country Law and Justice']]
# [['Drug Trafficking']]
# [['Environment']]
# [['Environment']]
# [['Environment', 'Indian Country Law and Justice']]
# [['Environment']]
# [['Civil Rights']]
# [['Drug Trafficking']]
# [['Counterterrorism']]
# [['Environment']]
# [['Consumer Protection', 'Health Care Fraud']]
# [['Financial Fraud']]
# [['Environment', 'Indian Country Law and Justice']]
# [['Consumer Protection', 'Environment']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Environment']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Immigration']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Elder Justice', 'False Claims Act', 'Health Care Fraud']]
# [['Opioids']]
# [['False Claims Act', 'Mortgage Fraud', 'StopFraud']]
# [['False Claims Act', 'Mortgage Fraud']]
# [['False Claims Act']]
# [['Consumer Protection']]
# [['False Claims Act']]
# [['Consumer Protection']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['Consumer Protection']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud', 'StopFraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act']]
# [['Project Safe Childhood']]
# [['False Claims Act']]
# [['Civil Rights']]
# [['Environment']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Asset Forfeiture', 'Foreign Corruption']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Asset Forfeiture', 'Foreign Corruption']]
# [['False Claims Act']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act', 'Health Care Fraud']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['Environment']]
# [['Financial Fraud', 'Mortgage Fraud', 'Securities, Commodities, & Investment Fraud', 'StopFraud']]
# [['Tax']]
# [['Consumer Protection']]
# [['False Claims Act']]
# [['False Claims Act', 'StopFraud']]
# [['Environment']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Drug Trafficking']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Health Care Fraud']]
# [['Opioids', 'Health Care Fraud']]
# [['Tax']]
# [['Counterterrorism', 'National Security']]
# [['False Claims Act']]
# [['Counterterrorism', 'National Security']]
# [['Environment']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism', 'National Security']]
# [['Public Corruption']]
# [['Office and Personnel Updates']]
# [['Office and Personnel Updates']]
# [['StopFraud']]
# [['Civil Rights']]
# [['Drug Trafficking', 'Firearms Offenses']]
# [['Consumer Protection']]
# [['Community Outreach']]
# [['Indian Country Law and Justice']]
# [['Office and Personnel Updates']]
# [['Office and Personnel Updates']]
# [['Cyber Crime', 'Intellectual Property']]
# [['Civil Rights']]
# [['Intellectual Property']]
# [['Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control']]
# [['Counterterrorism']]
# [['Consumer Protection']]
# [['Counterterrorism']]
# [['Consumer Protection']]
# [['Counterterrorism']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Public Corruption']]
# [['Environment']]
# [['Opioids', 'Grants']]
# [['Civil Rights']]
# [['Civil Rights']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Antitrust']]
# [['Environment']]
# [['Public Corruption']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['False Claims Act', 'Public Corruption']]
# [['False Claims Act']]
# [['Consumer Protection']]
# [['Environment']]
# [['False Claims Act']]
# [['Elder Justice', 'Financial Fraud', 'StopFraud']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption', 'StopFraud']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['Public Corruption']]
# [['National Security']]
# [['Counterintelligence and Export Control']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Tax']]
# [['Tax']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Asset Forfeiture', 'Foreign Corruption']]
# [['National Security']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Bankruptcy']]
# [['Consumer Protection']]
# [['Consumer Protection', 'Securities, Commodities, & Investment Fraud']]
# [['Civil Rights', 'Cyber Crime']]
# [['Hate Crimes']]
# [['False Claims Act', 'Mortgage Fraud']]
# [['Environment']]
# [['Firearms Offenses', 'Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['Tax']]
# [['Counterterrorism']]
# [['Counterterrorism']]
# [['Counterterrorism', 'National Security']]
# [['Tax']]
# [['Immigration']]
# [['Opioids', 'Drug Trafficking']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Firearms Offenses', 'Violent Crime']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Violent Crime']]
# [['Grants']]
# [['Hate Crimes']]
# [['Cyber Crime']]
# [['Asset Forfeiture', 'Foreign Corruption', 'Public Corruption']]
# [['Environment']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Public Corruption']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['False Claims Act']]
# [['Tax']]
# [['Tax']]
# [['Tax']]
# [['Counterintelligence and Export Control']]
# [['Counterterrorism']]
# [['Hate Crimes', 'Civil Rights']]
# [['Counterterrorism']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism', 'National Security']]
# [['Civil Rights', 'Hate Crimes']]
# [['Human Trafficking', 'Project Safe Childhood']]
# [['Counterterrorism', 'National Security']]
# [['Hate Crimes']]
# [['Project Safe Childhood']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism', 'National Security']]
# [['Tax']]
# [['Project Safe Childhood']]
# [['Identity Theft', 'Tax']]
# [['Consumer Protection']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Counterterrorism']]
# [['Human Trafficking', 'Project Safe Childhood']]
# [['Counterterrorism']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism']]
# [['Human Trafficking', 'Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Counterterrorism']]
# [['Project Safe Childhood']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Consumer Protection']]
# [['Project Safe Childhood']]
# [['Project Safe Childhood']]
# [['Tax']]
# [['StopFraud']]
# [['Consumer Protection']]
# [['Environment', 'Wildlife']]
# [['Tax']]
# [['Consumer Protection']]
# [['Tax']]
# [['Intellectual Property']]
# [['Intellectual Property']]
# [['Tax']]
# [['Tax']]
# [['Hate Crimes']]
# [['Identity Theft', 'Tax']]
# [['Identity Theft', 'Tax']]
# [['Intellectual Property']]
# [['Tax']]
# [['False Claims Act']]
# [['Environment', 'StopFraud']]
# [['Environment', 'Securities, Commodities, & Investment Fraud']]
# [['Environment']]
# [['Environment']]
# [['Environment']]
# [['Consumer Protection', 'Environment']]
# [['StopFraud']]
# [['Antitrust']]
# [['False Claims Act', 'Mortgage Fraud']]
# [['Consumer Protection', 'False Claims Act', 'Health Care Fraud']]
# [['Tax']]
# [['Tax']]
# [['Identity Theft', 'Tax']]
# [['Tax']]
# [['Public Corruption']]
# [['Antitrust']]
# [['Hate Crimes']]
# [['Hate Crimes']]
# [['False Claims Act']]
# [['Tax']]
# [['Tax']]
# [['Hate Crimes']]
# [['Antitrust']]
# [['Public Corruption']]
# [['False Claims Act']]
# [['Tax']]
# [['Tax']]
# [['StopFraud', 'Tax']]
# [['Tax']]
# [['Tax']]
# [['Hate Crimes']]
# [['False Claims Act']]
# [['Asset Forfeiture']]
# [['Access to Justice']]
# [['Access to Justice']]
# [['Violent Crime']]
# [['Counterterrorism', 'National Security']]
# [['Counterterrorism']]
# [['Firearms Offenses', 'Violent Crime']]
# [['Environment', 'Wildlife']]
# [['False Claims Act']]
# [['False Claims Act']]
# [['Project Safe Childhood']]
# [['Counterterrorism', 'National Security']]
# [['Project Safe Childhood']]
# [['Counterterrorism']]
# [['Civil Rights', 'Human Trafficking']]
# [['Tax']]
# [['Counterterrorism']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection']]
# [['Consumer Protection', 'Elder Justice']]
# [['Civil Rights', 'Human Trafficking']]
# [['Antitrust']]
# [['False Claims Act', 'Health Care Fraud']]
# [['Consumer Protection']]
# [['Civil Rights']]
# [['Environment']]
# [['Antitrust']]
# [['Counterterrorism']]
# [['Cyber Crime']]
# [['Hate Crimes']]
# [['Environment']]
# [['Foreign Corruption']]
# [['Asset Forfeiture', 'Counterintelligence and Export Control']]
# [['Counterintelligence and Export Control']]
