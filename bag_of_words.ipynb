# %%
import pandas as pd
import spacy

# %%
data = pd.read_csv('spam.csv')

# %%
data.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
#1 . first we will make new column in data to make spame as 1 and ham as 0.
#Logic 1.
data['spam_detector'] = data['Category'].apply(lambda x:1 if x =='spam' else 0)
#'spam_detector' is the new row which is made new

# %% [markdown]
# # Logic 2 (Mine) but this  will not work in Pandas this core python logic
# def sp(x):
#     if x == 'spam':
#         return 1
#     else:
#         return 0
#
# data['spam_detect_AADI'] = data['Category'].apply(sp)

# %%
data
# Out:
#      Category                                            Message  \
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
#       spam_detector
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0
# ...             ...
# 5567              1
# ...

# %%
# 2. Now Training and testing the data
from sklearn.model_selection import train_test_split
X_train , X_test ,y_train, y_test = train_test_split(data.Message , data.spam_detector , test_size = 0.5)

# %%
X_train.shape
# Out:
# (2786,)

# %%
X_train.values #this will tell you the data you are going to train
# Out:
# array(['Are you available for soiree on June 3rd?',
#        '22 days to kick off! For Euro2004 U will be kept up to date with the latest news and results daily. To be removed send GET TXT STOP to 83222',
#        'New Tones This week include: 1)McFly-All Ab.., 2) Sara Jorge-Shock.. 3) Will Smith-Switch.. To order follow instructions on next message',
#        ..., 'Tmrw. Im finishing 9 doors', 'Dear where you. Call me',
#        'Ever green quote ever told by Jerry in cartoon "A Person Who Irritates u Always Is the one Who Loves u Vry Much But Fails to Express It...!..!! :-) :-) gud nyt'],
#       dtype=object)

# %%
# 3. CountVectorizer for creating Bag of Words from sklearn
# Converting X_train samples and X_test samples into vectors using Countvectorizer()
from sklearn.feature_extraction.text import CountVectorizer
bag = CountVectorizer()
X_train_countvectorizer = bag.fit_transform(X_train.values)
X_test_countvectorizer=bag.transform(X_test)

# %%
#You get the bag of words here now!
dir(bag)[:1]
# Out:
# ['__annotations__']

# %%
bag.vocabulary_#this is the bag which contain words and there
# Out:
#   Cell In[222], line 1
#     bag.vocabulary_[]#this is the bag which contain words and there
#                     ^
# SyntaxError: invalid syntax

# %%
X_train[:4]
# Out:
# 1051            Are you available for soiree on June 3rd?
# 611     22 days to kick off! For Euro2004 U will be ke...
# 2680    New Tones This week include: 1)McFly-All Ab..,...
# 3873    I am joining today formally.Pls keep praying.w...
# Name: Message, dtype: object

# %% [markdown]
# There are the text converted into numbers in left

# %%
X_train[:4][1051] #Grabbing the sentence
# Out:
# 'Are you available for soiree on June 3rd?'

# %%
#4 Machine Learning Model on the data converted
#4.1 Importing and calling the model
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
#Multinomial Bayes is Goodfit for Text Classification problem

# %% [markdown]
# ✨ Types of Naive Bayes:
# Gaussian Naive Bayes:
#
# Used when features are continuous and normally distributed.
#
# Example: Predicting a label based on sensor data.
#
# Multinomial Naive Bayes:
#
# Used for discrete features, often in text classification.
#
# Example: Spam filtering using word frequencies.
#
# Bernoulli Naive Bayes:
#
# Used for binary features (e.g., word presence/absence).

# %%
#4.2 Fitting the X_train and y_train in Model
model.fit(X_train_countvectorizer,y_train)
# Out:
# MultinomialNB()

# %%
#4.3 Classification Report
#y_test is TRUTH and y_predict is the Models Prediction
from sklearn.metrics import classification_report
y_predict = model.predict(X_test_countvectorizer)
classification_report(y_test,y_predict)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      1.00      0.99      2410\n           1       0.97      0.90      0.94       376\n\n    accuracy                           0.98      2786\n   macro avg       0.98      0.95      0.96      2786\nweighted avg       0.98      0.98      0.98      2786\n'
