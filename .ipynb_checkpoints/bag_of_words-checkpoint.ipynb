# %%
import pandas as pd
import spacy

# %%
data = pd.read_csv('spam.csv')

# %%
data.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
#1 . first we will make new column in data to make spame as 1 and ham as 0.
#Logic 1.
data['spam_detector'] = data['Category'].apply(lambda x:1 if x =='spam' else 0)
#'spam_detector' is the new row which is made new

# %% [markdown]
# # Logic 2 (Mine) but this  will not work in Pandas this core python logic
# def sp(x):
#     if x == 'spam':
#         return 1
#     else:
#         return 0
#
# data['spam_detect_AADI'] = data['Category'].apply(sp)

# %%
data
# Out:
#      Category                                            Message  \
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
#       spam_detector
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0
# ...             ...
# 5567              1
# ...

# %%
# 2. Now Training and testing the data
from sklearn.model_selection import train_test_split
X_train , X_test ,y_train, y_test = train_test_split(data.Message , data.spam_detector , test_size = 0.5)

# %%
X_train.shape
# Out:
# (2786,)

# %%
X_train.values #this will tell you the data you are going to train
# Out:
# array(['Are you available for soiree on June 3rd?',
#        '22 days to kick off! For Euro2004 U will be kept up to date with the latest news and results daily. To be removed send GET TXT STOP to 83222',
#        'New Tones This week include: 1)McFly-All Ab.., 2) Sara Jorge-Shock.. 3) Will Smith-Switch.. To order follow instructions on next message',
#        ..., 'Tmrw. Im finishing 9 doors', 'Dear where you. Call me',
#        'Ever green quote ever told by Jerry in cartoon "A Person Who Irritates u Always Is the one Who Loves u Vry Much But Fails to Express It...!..!! :-) :-) gud nyt'],
#       dtype=object)

# %%
# 3. CountVectorizer for creating Bag of Words from sklearn
from sklearn.feature_extraction.text import CountVectorizer
bag = CountVectorizer()
X_train_countvectorizer = bag.fit_transform(X_train.values)

# %%
#You get the bag of words here now!
dir(bag)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_request_for_signature',
#  '_char_ngrams',
#  '_char_wb_ngrams',
#  '_check_feature_names',
#  '_check_n_features',
#  '_check_stop_words_consistency',
#  '_check_vocabulary',
#  '_count_vocab',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_limit_features',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
# ...

# %%
bag.vocabulary_ #this is the bag which contain words and there
# Out:
# {'are': 788,
#  'you': 5933,
#  'available': 869,
#  'for': 2242,
#  'soiree': 4817,
#  'on': 3793,
#  'june': 2970,
#  '3rd': 343,
#  '22': 266,
#  'days': 1673,
#  'to': 5317,
#  'kick': 3009,
#  'off': 3767,
#  'euro2004': 2029,
#  'will': 5783,
#  'be': 959,
#  'kept': 3001,
#  'up': 5514,
#  'date': 1664,
#  'with': 5805,
#  'the': 5221,
#  'latest': 3084,
#  'news': 3661,
#  'and': 721,
#  'results': 4407,
#  'daily': 1645,
#  'removed': 4365,
#  'send': 4612,
#  'get': 2381,
#  'txt': 5447,
#  'stop': 4973,
#  '83222': 492,
#  'new': 3657,
#  'tones': 5338,
#  'this': 5258,
#  'week': 5727,
#  'include': 2797,
#  'mcfly': 3374,
#  'all': 681,
#  'ab': 550,
#  'sara': 4523,
#  'jorge': 2956,
#  'shock': 4682,
#  'smith': 4794,
#  'switch': 5101,
#  'order': 3829,
#  'follow': 2227,
#  'instructions': 2842,
#  'next': 3662,
#  'message': 3419,
#  'am': 702,
#  'joining': 2947,
#  'today': 5320,
#  'formally': 2254,
#  'pls': 4032,
#  'keep': 2996,
#  'praying': 4119,
# ...
